# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import requests
from io import BytesIO
from PIL import Image
import urllib.request as ur
import re
import pandas as pd
from IPython.core.display import HTML
from urllib.request import urlopen
import pickle

# %%
# 1 : 경복궁(88~118) 2 : 창덕궁(27~42, 119~126) 3 : 창경궁(0~26) 4 : 덕수궁(71~87) 5 : 종묘(43~70)

# %%
# 1. 경복궁
driver = webdriver.Chrome("chromedriver.exe")

gyeongbokgung=[]
img_lst=[]
name=[]
kor_lst=[]
for i in range(151,168):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text
    # 이미지 url 리스트
    img_lst.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name.append(gung)
    kor_lst.append(kor)
    # 데이터프레임용
    gyeongbokgung.append([gung,kor,eng,jpa,chi])

for i in range(170,180):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text
    # 사진
    img_lst.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name.append(gung)
    kor_lst.append(kor)
    # 데이터프레임용
    gyeongbokgung.append([gung,kor,eng,jpa,chi])

    
for i in range(183,185):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n","").replace("<br />"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text.replace("\r\n","").replace("<br/>"," ")
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text.replace("\r\n","").replace("<br/>"," ")
    # 사진
    img_lst.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name.append(gung)
    kor_lst.append(kor)
    # 데이터프레임용
    gyeongbokgung.append([gung,kor,eng,jpa,chi])


url='https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number=186&detail_code=0&gung_number=3'
driver.get(url)
time.sleep(1)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
    
# 이름
gung=soup.find_all("contents_kor")[0].text
# 한글 해설
kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
pat=re.compile('<.+?>')
kor=re.sub(pat,"",kor_bf)
# 영문해설
eng=soup.find_all("explanation_eng")[0].text.replace("<br />"," ")
# 일본어 해설
jpa=soup.find_all("explanation_jpa")[0].text.replace("<br/>"," ")
# 중국어 해설
chi=soup.find_all("explanation_chi")[0].text.replace("<br/>"," ")
# 사진
# tkinter용
img_lst.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
name.append(gung)
kor_lst.append(kor)
gyeongbokgung.append([gung,kor,eng,jpa,chi])     
    
# img_lst
# Out:
# C:\Users\tjdbs\AppData\Local\Temp\ipykernel_15416\3970264868.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")

# %%
# idx=['경복궁' for x in range(len(gyeongbokgung))]

# %%
# 판다스로 저장
gyeongbokgung_list=pd.DataFrame(gyeongbokgung, columns = ['Contents','Explanation_kor', 'Explanation_eng','Explanation_jpa','Explanation_chi'])
gyeongbokgung_list.columns.name='경복궁'
gyeongbokgung_list.insert(0,'gung','경복궁')


# 데이터 프레임에 이미지 출력해주는 함수
def to_img_tag(path):
    return '<img src="'+ path + '" width="50" >'
# gyeongbokgung_list['Pictures']=img_lst
gyeongbokgung_list.insert(2,'Pictures',img_lst)
display(HTML(gyeongbokgung_list.to_html(escape=False,formatters=dict(Pictures=to_img_tag))))
# 경복궁 엑셀파일
gyeongbokgung_list.to_excel("4대궁및종묘/경복궁.xlsx", index=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>경복궁</th>
#       <th>gung</th>
#       <th>Contents</th>
#       <th>Pictures</th>
#       <th>Explanation_kor</th>
#       <th>Explanation_eng</th>
#       <th>Explanation_jpa</th>
#       <th>Explanation_chi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>경복궁</td>
#       <td>광화문</td>
#       <td><img src="https://www.heritage.go.kr/gung/gogung1/images/ic-c1.jpg" width="50" ></td>
#       <td>이곳은 경복궁의 남문, 광화문입니다. 요즘은 광화문 앞 세종로 양쪽으로 정부청사 건물들이 죽 늘어서 있지요? 조선시대에도 비슷했습니다. 광화문 앞은 의정부와 이조, 형조, 예조 등 육조 건물이 들어섰던 관청거리였거든요. 조선의 신하들은 해치를 바라보며 오늘도 공명정대하게 일을 하리라 다짐을 했답니다. 광화문은 역사의 증인이기도 합니다. 임진왜란 때는 불에 타고, 일제강점기에는 해체되어 다른 곳으로 이전되는 수모를 당하고 한국전쟁 때는 포화를 맞았지요. 그러다가 1968년 복원하였으나 목재가 아니라 철근, 콘크리트 건물로 잘못된 위치에 세워지고 맙니다.  다행히 경복궁 복원사업이 시작되면서 현재 광화문은 1867년 고종임금님이 중건 했을 당시의 모습을 되찾았습니다.</td>
# ...

# %%
# 2. 창덕궁
changdeokgung =[]
img_lst2=[]
name2=[]
kor_lst2=[]

for i in range(27,43):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text
    # 이미지 url 리스트
    img_lst2.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name2.append(gung)
    kor_lst2.append(kor)
    # 데이터프레임용
    changdeokgung.append([gung,kor,eng,jpa,chi])
    
for i in range(187,195):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text
    # 이미지 url 리스트
    img_lst2.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name2.append(gung)
    kor_lst2.append(kor)
    # 데이터프레임용
    changdeokgung.append([gung,kor,eng,jpa,chi])

changdeokgung
# Out:
# [['돈화문',
#   '이곳은 창덕궁의 정문인 돈화문입니다. 돈화(敦化)란 ‘임금이 큰 덕을 베풀어 백성들을 감화시킨다’는 의미로, 덕치를 숭상한 조선 임금(왕조)의 의지를 담고 있습니다.돈화문은, 임진왜란 때 소실되었다가 광해군 때 복원되었습니다. 월대라고 하는 돌로 쌓은 높은 대 위에 올려 있고, 그 한가운데 임금의 길인 어도가 길게 뻗어 있는 것을 보실 수 있습니다. 흥미로운 것은 다른 궁궐의 문은 모두 세 칸짜리인 데 반해 돈화문만 다섯 칸이라는 점입니다. 옛날에는 중국 황제만 다섯 칸짜리 대문을 쓸 수 있었습니다. 때문에 중국을 의식해 양쪽 끝에 문을 닫아 막아 놓았지만 외관만은 크고 장중하게 만들려고 했던 의도를 엿볼 수 있습니다.돈화문은 임금의 출입이나 국가의 큰 행사 때만 사용되는 상징적인 문이었고, 평소 신하나 군사들은 좌우 담장에 있는 금호문이나 단봉문, 경추문 등의 작은 문으로 출입했습니다. 궁궐 출입에는 엄격한 법도가 있었고 반드시 궁에서 발급하는 출입증을 가지고 다녀야 했습니다.돈화문 안마당으로 들어오시죠. 이곳에 자라는 여덟 그루의 회화나무가 보이시나요?  모두 천연기념물입니다.  자유롭게 뻗어나간 가지가 넓은 학문의 세계를 뜻한다 하여 선비나무라고도 하는데, 예로부터 궁궐이나 유학자의 집에는 이 회화나무를 심는 것이 전통이었습니다.',
# ...

# %%
# 판다스로 저장
changdeokgung_list=pd.DataFrame(changdeokgung, columns = ['Contents','Explanation_kor', 'Explanation_eng','Explanation_jpa','Explanation_chi'])
changdeokgung_list.columns.name='창덕궁'
changdeokgung_list.insert(0,'gung','창덕궁')
changdeokgung_list.insert(2,'Pictures',img_lst2)
display(HTML(changdeokgung_list.to_html(escape=False,formatters=dict(Pictures=to_img_tag))))

# 경복궁 엑셀파일
changdeokgung_list.to_excel("4대궁및종묘/창덕궁.xlsx", index=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>창덕궁</th>
#       <th>gung</th>
#       <th>Contents</th>
#       <th>Pictures</th>
#       <th>Explanation_kor</th>
#       <th>Explanation_eng</th>
#       <th>Explanation_jpa</th>
#       <th>Explanation_chi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>창덕궁</td>
#       <td>돈화문</td>
#       <td><img src="https://www.heritage.go.kr/gung/gogung2/images/img_changdeok_story_bg_00_00.jpg" width="50" ></td>
# ...

# %%
# 3. 창경궁
changgyeonggung=[]
img_lst3=[]
name3=[]
kor_lst3=[]
for i in range(0,27):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text
    # 이미지 url 리스트
    img_lst3.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name3.append(gung)
    kor_lst3.append(kor)
    # 데이터프레임용
    changgyeonggung.append([gung,kor,eng,jpa,chi])
changgyeonggung
# Out:
# [['홍화문',
#   '창경궁은 남향인 타 궁궐과 달리 동향으로 지어졌습니다. 1750년(영조 26년)에 영조는 균역법을 실시하기 전 홍화문 백성들에게 의견을 물어보았었고, 1795년(정조 19년)에 정조는 어머니인 혜경궁 홍씨의 회갑을 기념해, 이곳에서 가난한 백성들에게 직접 쌀을 나눠주기도 하였습니다.조선의 궁궐은 나라를 다스리는 법전까지 문이 세 개이지만 창경궁은 궁궐이 들어선 자리가 좁은 지형이기 때문에 홍화문에서 법전까지 문이 두 개 밖에 없습니다.',
# ...

# %%
# 판다스로 저장
changgyeonggung_list=pd.DataFrame(changgyeonggung, columns = ['Contents','Explanation_kor', 'Explanation_eng','Explanation_jpa','Explanation_chi'])
changgyeonggung_list.columns.name='창경궁'
changgyeonggung_list.insert(0,'gung','창경궁')
changgyeonggung_list.insert(2,'Pictures',img_lst3)
display(HTML(changgyeonggung_list.to_html(escape=False,formatters=dict(Pictures=to_img_tag))))

# 경복궁 엑셀파일
changgyeonggung_list.to_excel("4대궁및종묘/창경궁.xlsx", index=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>창경궁</th>
#       <th>gung</th>
#       <th>Contents</th>
#       <th>Pictures</th>
#       <th>Explanation_kor</th>
#       <th>Explanation_eng</th>
#       <th>Explanation_jpa</th>
#       <th>Explanation_chi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>창경궁</td>
#       <td>홍화문</td>
#       <td><img src="https://www.heritage.go.kr/gung/gogung3/images/img_changgyeong_story_bg_00_00.jpg" width="50" ></td>
#       <td>창경궁은 남향인 타 궁궐과 달리 동향으로 지어졌습니다. 1750년(영조 26년)에 영조는 균역법을 실시하기 전 홍화문 백성들에게 의견을 물어보았었고, 1795년(정조 19년)에 정조는 어머니인 혜경궁 홍씨의 회갑을 기념해, 이곳에서 가난한 백성들에게 직접 쌀을 나눠주기도 하였습니다.조선의 궁궐은 나라를 다스리는 법전까지 문이 세 개이지만 창경궁은 궁궐이 들어선 자리가 좁은 지형이기 때문에 홍화문에서 법전까지 문이 두 개 밖에 없습니다.</td>
# ...

# %%
# 4. 덕수궁
deoksugung=[]
img_lst4=[]
name4=[]
kor_lst4=[]
url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number=109&detail_code=0&gung_number=3'
driver.get(url)
time.sleep(1)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
    
# 이름
gung=soup.find_all("contents_kor")[0].text
# 한글 해설
kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
pat=re.compile('<.+?>')
kor=re.sub(pat,"",kor_bf)
# 영문해설
eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
# 일본어 해설
jpa=soup.find_all("explanation_jpa")[0].text
# 중국어 해설
chi=soup.find_all("explanation_chi")[0].text
# 이미지 url 리스트
img_lst4.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
# tkinter용
name4.append(gung)
kor_lst4.append(kor)
# 데이터프레임용
deoksugung.append([gung,kor,eng,jpa,chi])

for i in range(111,113):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text
    # 이미지 url 리스트
    img_lst4.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name4.append(gung)
    kor_lst4.append(kor)
    # 데이터프레임용
    deoksugung.append([gung,kor,eng,jpa,chi])
    
for i in range(117,131):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text
    # 이미지 url 리스트
    img_lst4.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name4.append(gung)
    kor_lst4.append(kor)
    # 데이터프레임용
    deoksugung.append([gung,kor,eng,jpa,chi])
deoksugung
# Out:
# [['대한문',
#   '대한문의 원래 이름은 대안문(大安門)으로 ‘나라가 편안하고 국민을 편안하게 하라’는 기원을 담은 이름입니다. 그와 달리 1906년 이름을 고쳐 단 대한문(大漢門)은 ‘한양이 창대해진다.’라는 의미를 지니고 있습니다. 지금 대한문의 위치는 처음 자리했던 곳이 아닙니다. 현재 위치에서 도로 앞쪽으로 33미터 남짓되는 곳이 원래 대한문이 있던 자리입니다. 일제강점기를 거치는 동안 태평로가 크게 뚫리면서 덕수궁 영역의 동쪽 부분이 크게 잠식당하였고, 광복 이후에도 또 다시 궁궐 담장이 뒤로 밀려나고 도로가 확장되면서 대한문만 외로이 도로 중간에 버려지듯이 서 있었던 시절도 있었습니다. 덕수궁에는 원래 남쪽을 향하던 인화문이라는 정문이 있었습니다. 그러나 인화문 방향의 도로가 협소하고, 대안문의 사용도가 높아지자 자연스럽게 대안문이 덕수궁의 정문이 되었습니다. 기록에 따르면, ‘대안문’이라는 편액이 처음 내걸린 것은 1899년의 일이었고, 다시 1906년에 ‘대한문’으로 현판을 고쳐 달게 되었습니다.',
# ...

# %%
# 판다스로 저장
deoksugung_list=pd.DataFrame(deoksugung, columns = ['Contents','Explanation_kor', 'Explanation_eng','Explanation_jpa','Explanation_chi'])
deoksugung_list.columns.name='덕수궁'
deoksugung_list.insert(0,'gung','덕수궁')
deoksugung_list.insert(2,'Pictures',img_lst4)
display(HTML(deoksugung_list.to_html(escape=False,formatters=dict(Pictures=to_img_tag))))
# 경복궁 엑셀파일
deoksugung_list.to_excel("4대궁및종묘/덕수궁.xlsx", index=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>덕수궁</th>
#       <th>gung</th>
#       <th>Contents</th>
#       <th>Pictures</th>
#       <th>Explanation_kor</th>
#       <th>Explanation_eng</th>
#       <th>Explanation_jpa</th>
#       <th>Explanation_chi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>덕수궁</td>
#       <td>대한문</td>
#       <td><img src="https://www.heritage.go.kr/gung/gogung4/images/mode_general_00_01.jpg" width="50" ></td>
# ...

# %%
# 5. 종묘
driver = webdriver.Chrome("chromedriver.exe")

seedling=[]
img_lst5=[]
name5=[]
kor_lst5=[]
for i in range(43,71):
    url=f'https://www.heritage.go.kr/heri/gungDetail/gogungDetailOpenApi.do?serial_number={i}&detail_code=0&gung_number=3'
    driver.get(url)
    time.sleep(1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # 이름
    gung=soup.find_all("contents_kor")[0].text
    # 한글 해설
    kor_bf=str(soup.find_all("explanation_kor")[0].text.replace("\r\n"," "))
    pat=re.compile('<.+?>')
    kor=re.sub(pat,"",kor_bf)
    # 영문해설
    eng=soup.find_all("explanation_eng")[0].text.replace("\r\n"," ")
    # 일본어 해설
    jpa=soup.find_all("explanation_jpa")[0].text
    # 중국어 해설
    chi=soup.find_all("explanation_chi")[0].text
    # 이미지 url 리스트
    img_lst5.append(soup.find_all("imgurl")[0].text.split("\n")[1].split("\t")[1].rstrip())
    # tkinter용
    name5.append(gung)
    kor_lst5.append(kor)
    # 데이터프레임용
    seedling.append([gung,kor,eng,jpa,chi])
seedling
# Out:
# C:\Users\tjdbs\AppData\Local\Temp\ipykernel_15416\3202235541.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# [['하마비',
#   '하마비(下馬碑)：하마비는 조선시대에 종묘나 궁궐 앞에 세워놓은 석비(石碑)입니다. 비에는 말을 타고 가는 자는 반드시 내려야한다는 글이 적혀있습니다. 중요한 국가의 제사 시설인 종묘와 왕의 가족이 머무는 궁궐에 대한 존경의 의미를 담고 있지요.종묘의 하마비는 종묘 시민공원에 있습니다. 공원이 조선시대에 종묘로 들어가는 길목이었기 때문이에요. 조선시대에 왕은 조상신에게 성대한 제사를 지내는 종묘제례를 통해 백성들에게 훌륭한 효의 본보기를 보였습니다.여기서 조선시대의 기본이념이 되었던 효를 중시하는 유교의 영향을 볼 수 있지요. 종묘 제례는 백성들의 가치관과 행동에 많은 영향을 주기도 했습니다. 종묘 하마비는 1663년 10월에 세워졌습니다.※사직：삼국시대부터 시작한 국가제사로 땅의 신과 곡식의 신에게 제사를 올렸던 장소. 종묘 하마비 : 태종실록 25권, 13년 1월 21일(신축) ‘종묘 및 궐문의 입구에 푯말을 세우다’로 기록됨.',
# ...

# %%
# 판다스로 저장
seedling_list=pd.DataFrame(seedling, columns = ['Contents','Explanation_kor', 'Explanation_eng','Explanation_jpa','Explanation_chi'])
seedling_list.columns.name='종묘'
seedling_list.insert(0,'gung','종묘')
seedling_list.insert(2,'Pictures',img_lst5)
display(HTML(seedling_list.to_html(escape=False,formatters=dict(Pictures=to_img_tag))))
# 경복궁 엑셀파일
seedling_list.to_excel("4대궁및종묘/종묘.xlsx", index=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>종묘</th>
#       <th>gung</th>
#       <th>Contents</th>
#       <th>Pictures</th>
#       <th>Explanation_kor</th>
#       <th>Explanation_eng</th>
#       <th>Explanation_jpa</th>
#       <th>Explanation_chi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>종묘</td>
#       <td>하마비</td>
#       <td><img src="https://www.heritage.go.kr/gung/gogung5/images/img_jongmyo_story_bg_00_00.jpg" width="50" ></td>
# ...

# %%
# 4대궁및종묘 데이터프레임 합쳐서 엑셀파일로 저장
gung_seedling_list=pd.concat([gyeongbokgung_list, changdeokgung_list,changgyeonggung_list,deoksugung_list,seedling_list],axis=0) #  ignore_index=True
gung_seedling_list.to_excel("4대궁및종묘/4대궁및종묘.xlsx", index=False)
gung_seedling_list
# Out:
#    gung Contents                                           Pictures  \
# 0   경복궁      광화문  https://www.heritage.go.kr/gung/gogung1/images...
# 1   경복궁      건춘문  https://www.heritage.go.kr/gung/gogung1/images...
# 2   경복궁      영추문  https://www.heritage.go.kr/gung/gogung1/images...
# 3   경복궁      신무문  https://www.heritage.go.kr/gung/gogung1/images...
# 4   경복궁     동십자각  https://www.heritage.go.kr/gung/gogung1/images...
# ..  ...      ...                                                ...
# 23   종묘   요대(燎臺)  https://www.heritage.go.kr/gung/gogung5/images...
# 24   종묘    정전 서문  https://www.heritage.go.kr/gung/gogung5/images...
# 25   종묘      영녕전  https://www.heritage.go.kr/gung/gogung5/images...
# 26   종묘  영녕전 악공청  https://www.heritage.go.kr/gung/gogung5/images...
# 27   종묘   정전 악공청  https://www.heritage.go.kr/gung/gogung5/images...
#
#                                       Explanation_kor  \
# 0   이곳은 경복궁의 남문, 광화문입니다. 요즘은 광화문 앞 세종로 양쪽으로 정부청사 건...
# ...

# %%
# # 4대궁및종묘 데이터프레임 합쳐서 엑셀파일로 저장
# groups_gung=gung_seedling_list.groupby(['gung','Contents'])
# groups_gung_lst=groups_gung.first()

# %%
gung_seedling_list=pd.read_excel("4대궁및종묘/4대궁및종묘.xlsx")
gung_seedling_list
# Out:
#     gung Contents                                           Pictures  \
# 0    경복궁      광화문  https://www.heritage.go.kr/gung/gogung1/images...
# 1    경복궁      건춘문  https://www.heritage.go.kr/gung/gogung1/images...
# 2    경복궁      영추문  https://www.heritage.go.kr/gung/gogung1/images...
# 3    경복궁      신무문  https://www.heritage.go.kr/gung/gogung1/images...
# 4    경복궁     동십자각  https://www.heritage.go.kr/gung/gogung1/images...
# ..   ...      ...                                                ...
# 121   종묘   요대(燎臺)  https://www.heritage.go.kr/gung/gogung5/images...
# 122   종묘    정전 서문  https://www.heritage.go.kr/gung/gogung5/images...
# 123   종묘      영녕전  https://www.heritage.go.kr/gung/gogung5/images...
# 124   종묘  영녕전 악공청  https://www.heritage.go.kr/gung/gogung5/images...
# 125   종묘   정전 악공청  https://www.heritage.go.kr/gung/gogung5/images...
#
#                                        Explanation_kor  \
# 0    이곳은 경복궁의 남문, 광화문입니다. 요즘은 광화문 앞 세종로 양쪽으로 정부청사 건...
# ...

# %%
# 데이터 프레임에 이미지 출력해주는 함수
def to_img_tag(path):
    return '<img src="'+ path + '" width="5000" >'
display(HTML(gung_seedling_list.to_html(escape=False,formatters=dict(Pictures=to_img_tag))))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gung</th>
#       <th>Contents</th>
#       <th>Pictures</th>
#       <th>Explanation_kor</th>
#       <th>Explanation_eng</th>
#       <th>Explanation_jpa</th>
#       <th>Explanation_chi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>경복궁</td>
#       <td>광화문</td>
#       <td><img src="https://www.heritage.go.kr/gung/gogung1/images/ic-c1.jpg" width="5000" ></td>
#       <td>이곳은 경복궁의 남문, 광화문입니다. 요즘은 광화문 앞 세종로 양쪽으로 정부청사 건물들이 죽 늘어서 있지요? 조선시대에도 비슷했습니다. 광화문 앞은 의정부와 이조, 형조, 예조 등 육조 건물이 들어섰던 관청거리였거든요. 조선의 신하들은 해치를 바라보며 오늘도 공명정대하게 일을 하리라 다짐을 했답니다. 광화문은 역사의 증인이기도 합니다. 임진왜란 때는 불에 타고, 일제강점기에는 해체되어 다른 곳으로 이전되는 수모를 당하고 한국전쟁 때는 포화를 맞았지요. 그러다가 1968년 복원하였으나 목재가 아니라 철근, 콘크리트 건물로 잘못된 위치에 세워지고 맙니다.  다행히 경복궁 복원사업이 시작되면서 현재 광화문은 1867년 고종임금님이 중건 했을 당시의 모습을 되찾았습니다.</td>
# ...

# %%
# 각 궁,종묘별로 문화재 몇 개인지 카운트
gung_seedling_list.groupby('gung')[['Contents']].count()
# Out:
#       Contents
# gung
# 경복궁         30
# 덕수궁         17
# 종묘          28
# 창경궁         27
# 창덕궁         24

# %%
gung_groups=gung_seedling_list.groupby('gung')[['Contents']]
gung_groups

# %%
# 경복궁 사진 저장
for i in range(0,len(img_lst)):
    ur.urlretrieve(img_lst[i],'4대궁및종묘/경복궁_사진/'+'경복궁'+str(i)+'.png')

# %%
# 창덕궁 사진 저장
for i in range(0,len(img_lst2)):
    ur.urlretrieve(img_lst2[i],'4대궁및종묘/창덕궁_사진/'+'창덕궁'+str(i)+'.png')

# %%
# 창경궁 사진 저장
for i in range(0,len(img_lst3)):
    ur.urlretrieve(img_lst3[i],'4대궁및종묘/창경궁_사진/'+'창경궁'+str(i)+'.png')

# %%
# 덕수궁 사진 저장
for i in range(0,len(img_lst4)):
    ur.urlretrieve(img_lst4[i],'4대궁및종묘/덕수궁_사진/'+'덕수궁'+str(i)+'.png')

# %%
# 종묘 사진 저장
for i in range(0,len(img_lst5)):
    ur.urlretrieve(img_lst5[i],'4대궁및종묘/종묘_사진/'+'종묘'+str(i)+'.png')

# %%
# 경복궁 이름
filePath = '4대궁및종묘/경복궁_이름.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(name, lf)

with open(filePath, 'rb') as lf:
    readList = pickle.load(lf)

# 경복궁 한글설명
filePath = '4대궁및종묘/경복궁_한글설명.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(kor_lst, lf)
    
filePath = '4대궁및종묘/경복궁_한글설명.txt'
with open(filePath, 'rb') as lf:
    korList = pickle.load(lf)

# %%
# 창덕궁 이름
filePath = '4대궁및종묘/창덕궁_이름.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(name2, lf)

with open(filePath, 'rb') as lf:
    readList2 = pickle.load(lf)

# 창덕궁 한글설명
filePath = '4대궁및종묘/창덕궁_한글설명.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(kor_lst2, lf)
    
filePath = '4대궁및종묘/창덕궁_한글설명.txt'
with open(filePath, 'rb') as lf:
    korList2 = pickle.load(lf)

# %%
len(korList2)
# Out:
# 24

# %%
# 창경궁 이름
filePath = '4대궁및종묘/창경궁_이름.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(name3, lf)

with open(filePath, 'rb') as lf:
    readList3 = pickle.load(lf)

# 창경궁 한글설명
filePath = '4대궁및종묘/창경궁_한글설명.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(kor_lst3, lf)
    
filePath = '4대궁및종묘/창경궁_한글설명.txt'
with open(filePath, 'rb') as lf:
    korList3 = pickle.load(lf)

# %%
# 덕수궁 이름
filePath = '4대궁및종묘/덕수궁_이름.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(name4, lf)

with open(filePath, 'rb') as lf:
    readList4 = pickle.load(lf)

# 덕수궁 한글설명
filePath = '4대궁및종묘/덕수궁_한글설명.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(kor_lst4, lf)
    
filePath = '4대궁및종묘/덕수궁_한글설명.txt'
with open(filePath, 'rb') as lf:
    korList4 = pickle.load(lf)

# %%
# 종묘 이름
filePath = '4대궁및종묘/종묘_이름.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(name5, lf)

with open(filePath, 'rb') as lf:
    readList5 = pickle.load(lf)

# 종묘 한글설명
filePath = '4대궁및종묘/종묘_한글설명.txt'
with open(filePath, 'wb') as lf:
    pickle.dump(kor_lst5, lf)
    
filePath = '4대궁및종묘/종묘_한글설명.txt'
with open(filePath, 'rb') as lf:
    korList5 = pickle.load(lf)
