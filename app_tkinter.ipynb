# %%
from tkinter import *
import tkinter.ttk
import random
from PIL import ImageTk
from PIL import ImageTk, Image
import pandas as pd
from IPython.core.display import HTML
import pickle
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure

# %%
###################################################################경복궁
# 다음 버튼 함수
num=0
def next_img():
    global num
    num += 1
    # 마지막 사진이 넘어가면 처음 사진으로 되돌아가기
    if num >= len(img_list):
        num=0
    canvas.itemconfig(can_img, image=img_list[num])
    canvas1_1.itemconfig(can_txt,text=readList[num])
    canvas1_2.itemconfig(can_txt2,text=korList[num])
    canvas1_3.itemconfig(can_txt3,text=page_lst[num])

# 이전 버튼 함수 
def pre_img():
    global num
    num -= 1
    if num < 0:
        num= len(img_list)-1
    canvas.itemconfig(can_img, image=img_list[num])
    canvas1_1.itemconfig(can_txt,text=readList[num])
    canvas1_2.itemconfig(can_txt2,text=korList[num])
    canvas1_3.itemconfig(can_txt3,text=page_lst[num])
###################################################################창덕궁
num2=0
def next_img2():
    global num2       
    num2 += 1
    if num2 >= len(img_list2):
        num2=0
    canvas2.itemconfig(can_img2, image=img_list2[num2])
    canvas2_1.itemconfig(can_txt2,text=readList2[num2])
    canvas2_2.itemconfig(can_txt2_2,text=korList2[num2])
    canvas2_3.itemconfig(can_txt2_3,text=page_lst2[num2])
def pre_img2():
    global num2
    num2 -= 1
    if num2 < 0:
        num2= len(img_list2)-1
    canvas2.itemconfig(can_img2, image=img_list2[num2])
    canvas2_1.itemconfig(can_txt2,text=readList2[num2])
    canvas2_2.itemconfig(can_txt2_2,text=korList2[num2])
    canvas2_3.itemconfig(can_txt2_3,text=page_lst2[num2])
####################################################################창경궁
num3=0
def next_img3():
    global num3        
    num3 += 1
    if num3 >= len(img_list3):
        num3=0
    canvas3.itemconfig(can_img3, image=img_list3[num3])
    canvas3_1.itemconfig(can_txt3,text=readList3[num3])
    canvas3_2.itemconfig(can_txt3_2,text=korList3[num3])
    canvas3_3.itemconfig(can_txt3_3,text=page_lst3[num3])
def pre_img3():
    global num3
    num3 -= 1
    if num3 < 0:
        num3= len(img_list3)-1
    canvas3.itemconfig(can_img3, image=img_list3[num3])
    canvas3_1.itemconfig(can_txt3,text=readList3[num3])
    canvas3_2.itemconfig(can_txt3_2,text=korList3[num3])
    canvas3_3.itemconfig(can_txt3_3,text=page_lst3[num3])
###################################################################덕수궁
num4=0
def next_img4():
    global num4       
    num4 += 1
    if num4 >= len(img_list4):
        num4=0
    canvas4.itemconfig(can_img4, image=img_list4[num4])
    canvas4_1.itemconfig(can_txt4,text=readList4[num4])
    canvas4_2.itemconfig(can_txt4_2,text=korList4[num4])
    canvas4_3.itemconfig(can_txt4_3,text=page_lst4[num4])
def pre_img4():
    global num4
    num4 -= 1
    if num4 < 0:
        num4= len(img_list4)-1
    canvas4.itemconfig(can_img4, image=img_list4[num4])
    canvas4_1.itemconfig(can_txt4,text=readList4[num4])
    canvas4_2.itemconfig(can_txt4_2,text=korList4[num4])
    canvas4_3.itemconfig(can_txt4_3,text=page_lst4[num4])
###################################################################종묘
num5=0
def next_img5():
    global num5      
    num5 += 1
    if num5 >= len(img_list5):
        num5=0
    canvas5.itemconfig(can_img5, image=img_list5[num5])
    canvas5_1.itemconfig(can_txt5,text=readList5[num5])
    canvas5_2.itemconfig(can_txt5_2,text=korList5[num5])
    canvas5_3.itemconfig(can_txt5_3,text=page_lst5[num5])
def pre_img5():
    global num5
    num5 -= 1
    if num5 < 0:
        num5= len(img_list5)-1
    canvas5.itemconfig(can_img5, image=img_list5[num5])
    canvas5_1.itemconfig(can_txt5,text=readList5[num5])
    canvas5_2.itemconfig(can_txt5_2,text=korList5[num5])
    canvas5_3.itemconfig(can_txt5_3,text=page_lst5[num5])

# %%
#1서울
img_num=0
def next_img_nt():
    global img_num      
    img_num += 1
    if img_num >= len(img_list):
        img_num=0
    canvas.itemconfig(can_img, image=img_list[img_num])
    canvas1_1.itemconfig(can_txt,text=readList[img_num])
    canvas1_2.itemconfig(can_txt1_2,text=korList[img_num])
    canvas1_2.itemconfig(can_txt1_3,text=page_lst[img_num])
    canvas_1.itemconfig(can_dt_txt,text=catList[img_num])
def pre_img_nt():
    global img_num
    img_num -= 1
    if img_num < 0:
        img_num= len(img_list)-1
    canvas.itemconfig(can_img, image=img_list[img_num])
    canvas1_1.itemconfig(can_txt,text=readList[img_num])
    canvas1_2.itemconfig(can_txt1_2,text=korList[img_num])
    canvas1_2.itemconfig(can_txt1_3,text=page_lst[img_num])
    canvas_1.itemconfig(can_dt_txt,text=catList[img_num])
#2부산
img_num2=0
def next_img_nt2():
    global img_num2      
    img_num2 += 1
    if img_num2 >= len(img_list2):
        img_num2=0
    canvas2.itemconfig(can_img2, image=img_list2[img_num2])
    canvas2_1.itemconfig(can_txt2,text=readList2[img_num2])
    canvas2_2.itemconfig(can_txt2_2,text=korList2[img_num2])
    canvas2_2.itemconfig(can_txt2_3,text=page_lst2[img_num2])
    canvas_2.itemconfig(can_dt_txt2,text=catList2[img_num2])
def pre_img_nt2():
    global img_num2
    img_num2 -= 1
    if img_num2 < 0:
        img_num2= len(img_list2)-1
    canvas2.itemconfig(can_img2, image=img_list2[img_num2])
    canvas2_1.itemconfig(can_txt2,text=readList2[img_num2])
    canvas2_2.itemconfig(can_txt2_2,text=korList2[img_num2])
    canvas1_2.itemconfig(can_txt2_3,text=page_lst2[img_num2])
    canvas_2.itemconfig(can_dt_txt2,text=catList2[img_num2])
#3대구
img_num3=0
def next_img_nt3():
    global img_num3     
    img_num3 += 1
    if img_num3 >= len(img_list3):
        img_num3=0
    canvas3.itemconfig(can_img3, image=img_list3[img_num3])
    canvas3_1.itemconfig(can_txt3,text=readList3[img_num3])
    canvas3_2.itemconfig(can_txt3_2,text=korList3[img_num3])
    canvas3_2.itemconfig(can_txt3_3,text=page_lst3[img_num3])
    canvas_3.itemconfig(can_dt_txt3,text=catList3[img_num3])
def pre_img_nt3():
    global img_num3
    img_num3 -= 1
    if img_num3 < 0:
        img_num3= len(img_list3)-1
    canvas3.itemconfig(can_img3, image=img_list3[img_num3])
    canvas3_1.itemconfig(can_txt3,text=readList3[img_num3])
    canvas3_2.itemconfig(can_txt3_2,text=korList3[img_num3])
    canvas3_2.itemconfig(can_txt3_3,text=page_lst3[img_num3])
    canvas_3.itemconfig(can_dt_txt3,text=catList3[img_num3])
#4광주
img_num4=0
def next_img_nt4():
    global img_num4    
    img_num4 += 1
    if img_num4 >= len(img_list4):
        img_num4=0
    canvas4.itemconfig(can_img4, image=img_list4[img_num4])
    canvas4_1.itemconfig(can_txt4,text=readList4[img_num4])
    canvas4_2.itemconfig(can_txt4_2,text=korList4[img_num4])
    canvas4_2.itemconfig(can_txt4_3,text=page_lst4[img_num4])
    canvas_4.itemconfig(can_dt_txt4,text=catList4[img_num4])
def pre_img_nt4():
    global img_num4
    img_num4 -= 1
    if img_num4 < 0:
        img_num4= len(img_list4)-1
    canvas4.itemconfig(can_img4, image=img_list4[img_num4])
    canvas4_1.itemconfig(can_txt4,text=readList4[img_num4])
    canvas4_2.itemconfig(can_txt4_2,text=korList4[img_num4])
    canvas4_2.itemconfig(can_txt4_3,text=page_lst4[img_num4])
    canvas_4.itemconfig(can_dt_txt4,text=catList4[img_num4])
#5인천
img_num5=0
def next_img_nt5():
    global img_num5    
    img_num5 += 1
    if img_num5 >= len(img_list5):
        img_num5=0
    canvas5.itemconfig(can_img5, image=img_list5[img_num5])
    canvas5_1.itemconfig(can_txt5,text=readList5[img_num5])
    canvas5_2.itemconfig(can_txt5_2,text=korList5[img_num5])
    canvas5_2.itemconfig(can_txt5_3,text=page_lst5[img_num5])
    canvas_5.itemconfig(can_dt_txt5,text=catList5[img_num5])
def pre_img_nt5():
    global img_num5
    img_num5 -= 1
    if img_num5 < 0:
        img_num5= len(img_list5)-1
    canvas5.itemconfig(can_img5, image=img_list5[img_num5])
    canvas5_1.itemconfig(can_txt5,text=readList5[img_num5])
    canvas5_2.itemconfig(can_txt5_2,text=korList5[img_num5])
    canvas5_2.itemconfig(can_txt5_3,text=page_lst5[img_num5])
    canvas_5.itemconfig(can_dt_txt5,text=catList5[img_num5])
#6대전
img_num6=0
def next_img_nt6():
    global img_num6    
    img_num6 += 1
    if img_num6 >= len(img_list6):
        img_num6=0
    canvas6.itemconfig(can_img6, image=img_list6[img_num6])
    canvas6_1.itemconfig(can_txt6,text=readList6[img_num6])
    canvas6_2.itemconfig(can_txt6_2,text=korList6[img_num6])
    canvas6_2.itemconfig(can_txt6_3,text=page_lst6[img_num6])
    canvas_6.itemconfig(can_dt_txt6,text=catList6[img_num6])
def pre_img_nt6():
    global img_num6
    img_num6 -= 1
    if img_num6 < 0:
        img_num6= len(img_list6)-1
    canvas6.itemconfig(can_img6, image=img_list6[img_num6])
    canvas6_1.itemconfig(can_txt6,text=readList6[img_num6])
    canvas6_2.itemconfig(can_txt6_2,text=korList6[img_num6])
    canvas6_2.itemconfig(can_txt6_3,text=page_lst6[img_num6])
    canvas_6.itemconfig(can_dt_txt6,text=catList6[img_num6])
#7울산
img_num7=0
def next_img_nt7():
    global img_num7  
    img_num7 += 1
    if img_num7 >= len(img_list7):
        img_num7=0
    canvas7.itemconfig(can_img7, image=img_list7[img_num7])
    canvas7_1.itemconfig(can_txt7,text=readList7[img_num7])
    canvas7_2.itemconfig(can_txt7_2,text=korList7[img_num7])
    canvas7_2.itemconfig(can_txt7_3,text=page_lst7[img_num7])
    canvas_7.itemconfig(can_dt_txt7,text=catList7[img_num7])
def pre_img_nt7():
    global img_num7
    img_num7 -= 1
    if img_num7 < 0:
        img_num7= len(img_list7)-1
    canvas7.itemconfig(can_img7, image=img_list7[img_num7])
    canvas7_1.itemconfig(can_txt7,text=readList7[img_num7])
    canvas7_2.itemconfig(can_txt7_2,text=korList7[img_num7])
    canvas7_2.itemconfig(can_txt7_3,text=page_lst7[img_num7])
    canvas_7.itemconfig(can_dt_txt7,text=catList7[img_num7])
#8경기
img_num8=0
def next_img_nt8():
    global img_num8  
    img_num8 += 1
    if img_num8 >= len(img_list8):
        img_num8=0
    canvas8.itemconfig(can_img8, image=img_list8[img_num8])
    canvas8_1.itemconfig(can_txt8,text=readList8[img_num8])
    canvas8_2.itemconfig(can_txt8_2,text=korList8[img_num8])
    canvas8_2.itemconfig(can_txt8_3,text=page_lst8[img_num8])
    canvas_8.itemconfig(can_dt_txt8,text=catList8[img_num8])
def pre_img_nt8():
    global img_num8
    img_num8 -= 1
    if img_num8 < 0:
        img_num8= len(img_list8)-1
    canvas8.itemconfig(can_img8, image=img_list8[img_num8])
    canvas8_1.itemconfig(can_txt8,text=readList8[img_num8])
    canvas8_2.itemconfig(can_txt8_2,text=korList8[img_num8])
    canvas8_2.itemconfig(can_txt8_3,text=page_lst8[img_num8])
    canvas_8.itemconfig(can_dt_txt8,text=catList8[img_num8])
#9강원
img_num9=0
def next_img_nt9():
    global img_num9  
    img_num9 += 1
    if img_num9 >= len(img_list9):
        img_num9=0
    canvas9.itemconfig(can_img9, image=img_list9[img_num9])
    canvas9_1.itemconfig(can_txt9,text=readList9[img_num9])
    canvas9_2.itemconfig(can_txt9_2,text=korList9[img_num9])
    canvas9_2.itemconfig(can_txt9_3,text=page_lst9[img_num9])
    canvas_9.itemconfig(can_dt_txt9,text=catList9[img_num9])
def pre_img_nt9():
    global img_num9
    img_num9 -= 1
    if img_num9 < 0:
        img_num9= len(img_list9)-1
    canvas9.itemconfig(can_img9, image=img_list9[img_num9])
    canvas9_1.itemconfig(can_txt9,text=readList9[img_num9])
    canvas9_2.itemconfig(can_txt9_2,text=korList9[img_num9])
    canvas9_2.itemconfig(can_txt9_3,text=page_lst9[img_num9])
    canvas_9.itemconfig(can_dt_txt9,text=catList9[img_num9])
#10충북
img_num10=0
def next_img_nt10():
    global img_num10 
    img_num10 += 1
    if img_num10 >= len(img_list10):
        img_num10=0
    canvas10.itemconfig(can_img10, image=img_list10[img_num10])
    canvas10_1.itemconfig(can_txt10,text=readList10[img_num10])
    canvas10_2.itemconfig(can_txt10_2,text=korList10[img_num10])
    canvas10_2.itemconfig(can_txt10_3,text=page_lst10[img_num10])
    canvas_10.itemconfig(can_dt_txt10,text=catList10[img_num10])
def pre_img_nt10():
    global img_num10
    img_num10 -= 1
    if img_num10 < 0:
        img_num10= len(img_list10)-1
    canvas10.itemconfig(can_img10, image=img_list10[img_num10])
    canvas10_1.itemconfig(can_txt10,text=readList10[img_num10])
    canvas10_2.itemconfig(can_txt10_2,text=korList10[img_num10])
    canvas10_2.itemconfig(can_txt10_3,text=page_lst10[img_num10])
    canvas_10.itemconfig(can_dt_txt10,text=catList10[img_num10])
#11충남
img_num11=0
def next_img_nt11():
    global img_num11 
    img_num11 += 1
    if img_num11 >= len(img_list11):
        img_num11=0
    canvas11.itemconfig(can_img11, image=img_list11[img_num11])
    canvas11_1.itemconfig(can_txt11,text=readList11[img_num11])
    canvas11_2.itemconfig(can_txt11_2,text=korList11[img_num11])
    canvas11_2.itemconfig(can_txt11_3,text=page_lst11[img_num11])
    canvas_11.itemconfig(can_dt_txt11,text=catList11[img_num11])
def pre_img_nt11():
    global img_num11
    img_num11 -= 1
    if img_num11 < 0:
        img_num11= len(img_list11)-1
    canvas11.itemconfig(can_img11, image=img_list11[img_num11])
    canvas11_1.itemconfig(can_txt11,text=readList11[img_num11])
    canvas11_2.itemconfig(can_txt11_2,text=korList11[img_num11])
    canvas11_2.itemconfig(can_txt11_3,text=page_lst11[img_num11])
    canvas_11.itemconfig(can_dt_txt11,text=catList11[img_num11])
#12전북
img_num12=0
def next_img_nt12():
    global img_num12
    img_num12 += 1
    if img_num12 >= len(img_list12):
        img_num12=0
    canvas12.itemconfig(can_img12, image=img_list12[img_num12])
    canvas12_1.itemconfig(can_txt12,text=readList12[img_num12])
    canvas12_2.itemconfig(can_txt12_2,text=korList12[img_num12])
    canvas12_2.itemconfig(can_txt12_3,text=page_lst12[img_num12])
    canvas_12.itemconfig(can_dt_txt12,text=catList12[img_num12])
def pre_img_nt12():
    global img_num12
    img_num12 -= 1
    if img_num12 < 0:
        img_num12= len(img_list12)-1
    canvas12.itemconfig(can_img12, image=img_list12[img_num12])
    canvas12_1.itemconfig(can_txt12,text=readList12[img_num12])
    canvas12_2.itemconfig(can_txt12_2,text=korList12[img_num12])
    canvas12_2.itemconfig(can_txt12_3,text=page_lst12[img_num12])
    canvas_12.itemconfig(can_dt_txt12,text=catList12[img_num12])
#13전남
img_num13=0
def next_img_nt13():
    global img_num13
    img_num13 += 1
    if img_num13 >= len(img_list13):
        img_num13=0
    canvas13.itemconfig(can_img13, image=img_list13[img_num13])
    canvas13_1.itemconfig(can_txt13,text=readList13[img_num13])
    canvas13_2.itemconfig(can_txt13_2,text=korList13[img_num13])
    canvas13_2.itemconfig(can_txt13_3,text=page_lst13[img_num13])
    canvas_13.itemconfig(can_dt_txt13,text=catList13[img_num13])
def pre_img_nt13():
    global img_num13
    img_num13 -= 1
    if img_num13 < 0:
        img_num13= len(img_list13)-1
    canvas13.itemconfig(can_img13, image=img_list13[img_num13])
    canvas13_1.itemconfig(can_txt13,text=readList13[img_num13])
    canvas13_2.itemconfig(can_txt13_2,text=korList13[img_num13])
    canvas13_2.itemconfig(can_txt13_3,text=page_lst13[img_num13])
    canvas_13.itemconfig(can_dt_txt13,text=catList13[img_num13])
#14경북
img_num14=0
def next_img_nt14():
    global img_num14
    img_num14 += 1
    if img_num14 >= len(img_list14):
        img_num14=0
    canvas14.itemconfig(can_img14, image=img_list14[img_num14])
    canvas14_1.itemconfig(can_txt14,text=readList14[img_num14])
    canvas14_2.itemconfig(can_txt14_2,text=korList14[img_num14])
    canvas14_2.itemconfig(can_txt14_3,text=page_lst14[img_num14])
    canvas_14.itemconfig(can_dt_txt14,text=catList14[img_num14])
def pre_img_nt14():
    global img_num14
    img_num14 -= 1
    if img_num14 < 0:
        img_num14= len(img_list14)-1
    canvas14.itemconfig(can_img14, image=img_list14[img_num14])
    canvas14_1.itemconfig(can_txt14,text=readList14[img_num14])
    canvas14_2.itemconfig(can_txt14_2,text=korList14[img_num14])
    canvas14_2.itemconfig(can_txt14_3,text=page_lst14[img_num14])
    canvas_14.itemconfig(can_dt_txt14,text=catList14[img_num14])
#15경남
img_num15=0
def next_img_nt15():
    global img_num15
    img_num15 += 1
    if img_num15 >= len(img_list15):
        img_num15=0
    canvas15.itemconfig(can_img15, image=img_list15[img_num15])
    canvas15_1.itemconfig(can_txt15,text=readList15[img_num15])
    canvas15_2.itemconfig(can_txt15_2,text=korList15[img_num15])
    canvas15_2.itemconfig(can_txt15_3,text=page_lst15[img_num15])
    canvas_15.itemconfig(can_dt_txt15,text=catList15[img_num15])
def pre_img_nt15():
    global img_num15
    img_num15 -= 1
    if img_num15 < 0:
        img_num15= len(img_list15)-1
    canvas15.itemconfig(can_img15, image=img_list15[img_num15])
    canvas15_1.itemconfig(can_txt15,text=readList15[img_num15])
    canvas15_2.itemconfig(can_txt15_2,text=korList15[img_num15])
    canvas15_2.itemconfig(can_txt15_3,text=page_lst15[img_num15])
    canvas_15.itemconfig(can_dt_txt15,text=catList15[img_num15])

# %%
#### 4대궁 및 종묘 버튼
def click_btn():
    # 윈도우 새 창(버튼 클릭시 새창이 뜨도록)
    window2 = Toplevel(window)
    window2.title("4대궁 및 종묘")
    # 창 사이즈
    window2.geometry("800x800")
    # 창을 고정
    window2.resizable(False, False)
    window2.config(padx=10, pady=10)
    st=tkinter.ttk.Style()
    st.theme_use('clam')
    # 탭 윈도우 노트북
    notebook=tkinter.ttk.Notebook(window2,width=800, height=800)
    notebook.pack()
    #########################################첫 번째 탭-경복궁########################################################
    # 메인 프레임
    frame1=tkinter.LabelFrame(window2, width=800, height=800, highlightcolor="purple")
    notebook.add(frame1, text="경복궁") 
    label = tkinter.Label(frame1,text = '경복궁의 문화재',font=("나눔바른펜", 15, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame1, relief="solid", bd=1)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame1)
    r_frame.pack(side="bottom", fill="both", expand=True)    
   
    # 이전, 다음 버튼 함수(왜인지는 모르겠으나 한번 더 함수를 지정해야 실행이 된다..)
    num=0
    def next_img():
        global num
        num += 1
        # 마지막 사진이 넘어가면 처음 사진으로 되돌아가기
        if num >= len(img_list):
            num=0
        canvas.itemconfig(can_img, image=img_list[num])
        canvas1_1.itemconfig(can_txt,text=readList[num])
        canvas1_2.itemconfig(can_txt2,text=korList[num])
        canvas1_3.itemconfig(can_txt3,text=page_lst[num])

    # 이전 버튼 함수 
    def pre_img():
        global num
        num -= 1
        if num < 0:
            num= len(img_list)-1
        canvas.itemconfig(can_img, image=img_list[num])
        canvas1_1.itemconfig(can_txt,text=readList[num])
        canvas1_2.itemconfig(can_txt2,text=korList[num])
        canvas1_3.itemconfig(can_txt3,text=page_lst[num])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath = '4대궁및종묘/경복궁_이름.txt'
    with open(filePath, 'rb') as lf:
        readList = pickle.load(lf)
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas1_1=Canvas(l_frame,height=40,width=200)
    canvas1_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas=Canvas(l_frame)
    canvas.pack(side='top')

    # 스크랩해온 경복궁 사진 불러오기
    img_list=[]
    page_lst=[]
    for i in range(0,30):
        page=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org=Image.open(f"4대궁및종묘/경복궁_사진/경복궁{i}.png")
        img_re=img_org.resize((400,300),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img=ImageTk.PhotoImage(img_re,master=window2)
        img_list.append(img)
        page_lst.append(page)
    # 그림 픽셀 위치
    can_img=canvas.create_image(200,150,image=img_list[num]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt=canvas1_1.create_text(100,30,text=readList[num],font=("나눔바른펜", 15, "bold"))  
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath = '4대궁및종묘/경복궁_한글설명.txt'
    with open(filePath, 'rb') as lf:
        korList = pickle.load(lf)
        
    canvas1_2=Canvas(r_frame,width=380, height=350,bg='ivory')
    canvas1_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt2=canvas1_2.create_text(380,180,text=korList[num],font=("나눔바른펜", 10, "bold"),width=600)
    # page 번호
    canvas1_3=Canvas(r_frame)
    canvas1_3.pack(side='bottom',fill="both", expand=True)
    can_txt3=canvas1_3.create_text(380,20,text=page_lst[num],font=("나눔바른펜", 9, "bold"),width=100)
   
    ##############################################두 번째 탭-창덕궁###############################################
    frame2=tkinter.Frame(window2, width=800, height=800)
    notebook.add(frame2, text="창덕궁")
    label = tkinter.Label(frame2,text = '창덕궁의 문화재',font=("나눔바른펜", 15, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame2, relief="solid", bd=1)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame2)
    r_frame.pack(side="bottom", fill="both", expand=True)    
    
    num2=0
    def next_img2():
        global num2       
        num2 += 1
        if num2 >= len(img_list2):
            num2=0
        canvas2.itemconfig(can_img2, image=img_list2[num2])
        canvas2_1.itemconfig(can_txt2,text=readList2[num2])
        canvas2_2.itemconfig(can_txt2_2,text=korList2[num2])
        canvas2_3.itemconfig(can_txt2_3,text=page_lst2[num2])
    def pre_img2():
        global num2
        num2 -= 1
        if num2 < 0:
            num2= len(img_list2)-1
        canvas2.itemconfig(can_img2, image=img_list2[num2])
        canvas2_1.itemconfig(can_txt2,text=readList2[num2])
        canvas2_2.itemconfig(can_txt2_2,text=korList2[num2])
        canvas2_3.itemconfig(can_txt2_3,text=page_lst2[num2])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img2)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img2)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath2 = '4대궁및종묘/창덕궁_이름.txt'
    with open(filePath2, 'rb') as lf:
        readList2 = pickle.load(lf)
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas2_1=Canvas(l_frame,height=40,width=200)
    canvas2_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas2=Canvas(l_frame)
    canvas2.pack(side='top')

    # 스크랩해온 창덕궁 사진 불러오기
    img_list2=[]
    page_lst2=[]
    for i in range(0,24):
        page2=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org2=Image.open(f"4대궁및종묘/창덕궁_사진/창덕궁{i}.png")
        img_re2=img_org2.resize((400,300),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img2=ImageTk.PhotoImage(img_re2,master=window2)
        img_list2.append(img2)
        page_lst2.append(page2)
    # 그림 픽셀 위치
    can_img2=canvas2.create_image(200,150,image=img_list2[num2]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt2=canvas2_1.create_text(100,30,text=readList2[num2],font=("나눔바른펜", 15, "bold"))  
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath2 = '4대궁및종묘/창덕궁_한글설명.txt'
    with open(filePath2, 'rb') as lf:
        korList2 = pickle.load(lf)
        
    canvas2_2=Canvas(r_frame,width=380, height=350,bg='ivory')
    canvas2_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt2_2=canvas2_2.create_text(380,180,text=korList2[num2],font=("나눔바른펜", 10, "bold"),width=600)
    # page 번호
    canvas2_3=Canvas(r_frame)
    canvas2_3.pack(side='bottom',fill="both", expand=True)
    can_txt2_3=canvas2_3.create_text(380,20,text=page_lst2[num2],font=("나눔바른펜", 9, "bold"),width=100)

    #############################################세 번째 탭-창경궁#########################################################
    frame3=tkinter.Frame(window2, width=800, height=800)
    notebook.add(frame3, text="창경궁")
    label = tkinter.Label(frame3,text = '창경궁의 문화재',font=("나눔바른펜", 15, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame3, relief="solid", bd=2)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame3)
    r_frame.pack(side="bottom", fill="both", expand=True)    
   
    num3=0
    def next_img3():
        global num3        
        num3 += 1
        if num3 >= len(img_list3):
            num3=0
        canvas3.itemconfig(can_img3, image=img_list3[num3])
        canvas3_1.itemconfig(can_txt3,text=readList3[num3])
        canvas3_2.itemconfig(can_txt3_2,text=korList3[num3])
        canvas3_3.itemconfig(can_txt3_3,text=page_lst3[num3])
    def pre_img3():
        global num3
        num3 -= 1
        if num3 < 0:
            num3= len(img_list3)-1
        canvas3.itemconfig(can_img3, image=img_list3[num3])
        canvas3_1.itemconfig(can_txt3,text=readList3[num3])
        canvas3_2.itemconfig(can_txt3_2,text=korList3[num3])
        canvas3_3.itemconfig(can_txt3_3,text=page_lst3[num3])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img3)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img3)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath3 = '4대궁및종묘/창경궁_이름.txt'
    with open(filePath3, 'rb') as lf:
        readList3 = pickle.load(lf)
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas3_1=Canvas(l_frame,height=40,width=200)
    canvas3_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas3=Canvas(l_frame)
    canvas3.pack(side='top')

    # 스크랩해온 창경궁 사진 불러오기
    img_list3=[]
    page_lst3=[]
    for i in range(0,27):
        page3=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org3=Image.open(f"4대궁및종묘/창경궁_사진/창경궁{i}.png")
        img_re3=img_org3.resize((400,300),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img3=ImageTk.PhotoImage(img_re3,master=window2)
        img_list3.append(img3)
        page_lst3.append(page3)
    # 그림 픽셀 위치
    can_img3=canvas3.create_image(200,150,image=img_list3[num3]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt3=canvas3_1.create_text(100,30,text=readList3[num3],font=("나눔바른펜", 15, "bold"))  
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath3 = '4대궁및종묘/창경궁_한글설명.txt'
    with open(filePath3, 'rb') as lf:
        korList3 = pickle.load(lf)
        
    canvas3_2=Canvas(r_frame,width=380, height=350,bg='ivory')
    canvas3_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt3_2=canvas3_2.create_text(380,180,text=korList3[num3],font=("나눔바른펜", 10, "bold"),width=600)
    # page 번호
    canvas3_3=Canvas(r_frame)
    canvas3_3.pack(side='bottom',fill="both", expand=True)
    can_txt3_3=canvas3_3.create_text(380,20,text=page_lst3[num3],font=("나눔바른펜", 9, "bold"),width=100)

    ################################################네 번째 탭-덕수궁##############################################
    frame4=tkinter.Frame(window2, width=800, height=800)
    notebook.add(frame4, text="덕수궁")
    label = tkinter.Label(frame4,text = '덕수궁의 문화재',font=("나눔바른펜", 15, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame4, relief="solid", bd=1)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame4)
    r_frame.pack(side="bottom", fill="both", expand=True)    
   
    num4=0
    def next_img4():
        global num4       
        num4 += 1
        if num4 >= len(img_list4):
            num4=0
        canvas4.itemconfig(can_img4, image=img_list4[num4])
        canvas4_1.itemconfig(can_txt4,text=readList4[num4])
        canvas4_2.itemconfig(can_txt4_2,text=korList4[num4])
        canvas4_3.itemconfig(can_txt4_3,text=page_lst4[num4])
    def pre_img4():
        global num4
        num4 -= 1
        if num4 < 0:
            num4= len(img_list4)-1
        canvas4.itemconfig(can_img4, image=img_list4[num4])
        canvas4_1.itemconfig(can_txt4,text=readList4[num4])
        canvas4_2.itemconfig(can_txt4_2,text=korList4[num4])
        canvas4_3.itemconfig(can_txt4_3,text=page_lst4[num4])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img4)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img4)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath4 = '4대궁및종묘/덕수궁_이름.txt'
    with open(filePath4, 'rb') as lf:
        readList4 = pickle.load(lf)
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas4_1=Canvas(l_frame,height=40,width=200)
    canvas4_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas4=Canvas(l_frame)
    canvas4.pack(side='top')

    # 스크랩해온 덕수궁 사진 불러오기
    img_list4=[]
    page_lst4=[]
    for i in range(0,17):
        page4=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org4=Image.open(f"4대궁및종묘/덕수궁_사진/덕수궁{i}.png")
        img_re4=img_org4.resize((400,300),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img4=ImageTk.PhotoImage(img_re4,master=window2)
        img_list4.append(img4)
        page_lst4.append(page4)
    # 그림 픽셀 위치
    can_img4=canvas4.create_image(200,150,image=img_list4[num4]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt4=canvas4_1.create_text(100,30,text=readList4[num4],font=("나눔바른펜", 15, "bold"))  
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath4 = '4대궁및종묘/덕수궁_한글설명.txt'
    with open(filePath4, 'rb') as lf:
        korList4 = pickle.load(lf)
        
    canvas4_2=Canvas(r_frame,width=380, height=350,bg='ivory')
    canvas4_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt4_2=canvas4_2.create_text(380,180,text=korList4[num4],font=("나눔바른펜", 10, "bold"),width=600)
    # page 번호
    canvas4_3=Canvas(r_frame)
    canvas4_3.pack(side='bottom',fill="both", expand=True)
    can_txt4_3=canvas4_3.create_text(380,20,text=page_lst4[num4],font=("나눔바른펜", 9, "bold"),width=100)


    #####################다섯 번째 탭-종묘############################
    frame5=tkinter.Frame(window2, width=800, height=800)
    notebook.add(frame5, text="종묘")
    label = tkinter.Label(frame5,text = '종묘의 문화재',font=("나눔바른펜", 15, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame5, relief="solid", bd=1)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame5)
    r_frame.pack(side="bottom", fill="both", expand=True)    
   
    num5=0
    def next_img5():
        global num5      
        num5 += 1
        if num5 >= len(img_list5):
            num5=0
        canvas5.itemconfig(can_img5, image=img_list5[num5])
        canvas5_1.itemconfig(can_txt5,text=readList5[num5])
        canvas5_2.itemconfig(can_txt5_2,text=korList5[num5])
        canvas5_3.itemconfig(can_txt5_3,text=page_lst5[num5])
    def pre_img5():
        global num5
        num5 -= 1
        if num5 < 0:
            num5= len(img_list5)-1
        canvas5.itemconfig(can_img5, image=img_list5[num5])
        canvas5_1.itemconfig(can_txt5,text=readList5[num5])
        canvas5_2.itemconfig(can_txt5_2,text=korList5[num5])
        canvas5_3.itemconfig(can_txt5_3,text=page_lst5[num5])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img5)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img5)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath5 = '4대궁및종묘/종묘_이름.txt'
    with open(filePath5, 'rb') as lf:
        readList5 = pickle.load(lf)
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas5_1=Canvas(l_frame,height=40,width=200)
    canvas5_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas5=Canvas(l_frame)
    canvas5.pack(side='top')

    # 스크랩해온 종묘 사진 불러오기
    img_list5=[]
    page_lst5=[]
    for i in range(0,28):
        page5=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org5=Image.open(f"4대궁및종묘/종묘_사진/종묘{i}.png")
        img_re5=img_org5.resize((400,300),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img5=ImageTk.PhotoImage(img_re5,master=window2)
        img_list5.append(img5)
        page_lst5.append(page5)
    # 그림 픽셀 위치
    can_img5=canvas5.create_image(200,150,image=img_list5[num5]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt5=canvas5_1.create_text(100,30,text=readList5[num5],font=("나눔바른펜", 15, "bold"))  
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath5 = '4대궁및종묘/종묘_한글설명.txt'
    with open(filePath5, 'rb') as lf:
        korList5 = pickle.load(lf)
        
    canvas5_2=Canvas(r_frame,width=380, height=350,bg='ivory')
    canvas5_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt5_2=canvas5_2.create_text(380,180,text=korList5[num5],font=("나눔바른펜", 10, "bold"),width=600)
    # page 번호
    canvas5_3=Canvas(r_frame)
    canvas5_3.pack(side='bottom',fill="both", expand=True)
    can_txt5_3=canvas5_3.create_text(380,20,text=page_lst5[num5],font=("나눔바른펜", 9, "bold"),width=100)
      
    window2.mainloop()
    
#########국보 버튼
def click_btn2():
    # 윈도우 새 창(버튼 클릭시 새창이 뜨도록)
    window3 = Toplevel(window)
    window3.title("국보")
    # 창 사이즈
    window3.geometry("800x800")
    # 창을 고정
    window3.resizable(False, False)
    window3.config(padx=10, pady=10)
    # 탭 윈도우 노트북
    notebook=tkinter.ttk.Notebook(window3,width=800, height=800)
    notebook.pack()
    #########################################첫 번째 탭-서울########################################################
    # 메인 프레임
    frame1=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame1, text="서울") 
    label = tkinter.Label(frame1,text = '서울의 국보 168점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame1, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame1)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    # 이전, 다음 버튼 함수(왜인지는 모르겠으나 한번 더 함수를 지정해야 실행이 된다..)
    img_num=0
    def next_img_nt():
        global img_num      
        img_num += 1
        if img_num >= len(img_list):
            img_num=0
        canvas.itemconfig(can_img, image=img_list[img_num])
        canvas1_1.itemconfig(can_txt,text=readList[img_num])
        canvas1_2.itemconfig(can_txt1_2,text=korList[img_num])
        canvas1_2.itemconfig(can_txt1_3,text=page_lst[img_num])
        canvas_1.itemconfig(can_dt_txt,text=catList[img_num])
    def pre_img_nt():
        global img_num
        img_num -= 1
        if img_num < 0:
            img_num= len(img_list)-1
        canvas.itemconfig(can_img, image=img_list[img_num])
        canvas1_1.itemconfig(can_txt,text=readList[img_num])
        canvas1_2.itemconfig(can_txt1_2,text=korList[img_num])
        canvas1_2.itemconfig(can_txt1_3,text=page_lst[img_num])
        canvas_1.itemconfig(can_dt_txt,text=catList[img_num])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath = '4대궁및종묘/국보_지역/서울/서울국보_이름.txt'
    with open(filePath, 'rb') as lf:
        readList = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath = '4대궁및종묘/국보_지역/서울/서울국보_분류및소재지.txt'
    with open(filePath, 'rb') as lf:
        catList = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas1_1=Canvas(l_frame,height=37,width=1000)
    canvas1_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas=Canvas(l_frame)
    canvas.pack(side='left')
    # 세부 설명
    canvas_1=Canvas(l_frame,height=200,width=300)
    canvas_1.pack(side='right')

    # 사진 불러오기
    img_list=[]
    page_lst=[]
    for i in range(0,168):
        page=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org=Image.open(f"4대궁및종묘/국보_사진/서울/국보{i}.png")
        img_re=img_org.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img=ImageTk.PhotoImage(img_re,master=window3)
        img_list.append(img)
        page_lst.append(page)
    # 그림 픽셀 위치
    can_img=canvas.create_image(200,140,image=img_list[img_num]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt=canvas1_1.create_text(310,27,text=readList[img_num],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt=canvas_1.create_text(140,60,text=catList[img_num],font=("나눔바른펜", 12, "bold"),width=200)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath = '4대궁및종묘/국보_지역/서울/서울국보_한글설명.txt'
    with open(filePath, 'rb') as lf:
        korList = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas1_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas1_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt1_2=canvas1_2.create_text(380,190,text=korList[img_num],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt1_3=canvas1_2.create_text(380,380,text=page_lst[img_num],font=("나눔바른펜", 9, "bold"),width=100)
    
    #########################################두 번째 탭-부산########################################################
    # 메인 프레임
    frame2=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame2, text="부산") 
    label = tkinter.Label(frame2,text = '부산의 국보 6점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame2, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame2)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    # 이전, 다음 버튼 함수(왜인지는 모르겠으나 한번 더 함수를 지정해야 실행이 된다..)
    img_num2=0
    def next_img_nt2():
        global img_num2      
        img_num2 += 1
        if img_num2 >= len(img_list2):
            img_num2=0
        canvas2.itemconfig(can_img2, image=img_list2[img_num2])
        canvas2_1.itemconfig(can_txt2,text=readList2[img_num2])
        canvas2_2.itemconfig(can_txt2_2,text=korList2[img_num2])
        canvas2_2.itemconfig(can_txt2_3,text=page_lst2[img_num2])
        canvas_2.itemconfig(can_dt_txt2,text=catList2[img_num2])
    def pre_img_nt2():
        global img_num2
        img_num2 -= 1
        if img_num2 < 0:
            img_num2= len(img_list2)-1
        canvas2.itemconfig(can_img2, image=img_list2[img_num2])
        canvas2_1.itemconfig(can_txt2,text=readList2[img_num2])
        canvas2_2.itemconfig(can_txt2_2,text=korList2[img_num2])
        canvas2_2.itemconfig(can_txt2_3,text=page_lst2[img_num2])
        canvas_2.itemconfig(can_dt_txt2,text=catList2[img_num2])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt2)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt2)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath2 = '4대궁및종묘/국보_지역/부산/부산국보_이름.txt'
    with open(filePath2, 'rb') as lf:
        readList2 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath2 = '4대궁및종묘/국보_지역/부산/부산국보_분류및소재지.txt'
    with open(filePath2, 'rb') as lf:
        catList2 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas2_1=Canvas(l_frame,height=37,width=1000)
    canvas2_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas2=Canvas(l_frame)
    canvas2.pack(side='left')
    # 세부 설명
    canvas_2=Canvas(l_frame,height=180,width=300)
    canvas_2.pack(side='right')

    # 사진 불러오기
    img_list2=[]
    page_lst2=[]
    for i in range(0,6):
        page2=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org2=Image.open(f"4대궁및종묘/국보_사진/부산/국보{i}.png")
        img_re2=img_org2.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img2=ImageTk.PhotoImage(img_re2,master=window3)
        img_list2.append(img2)
        page_lst2.append(page2)
    # 그림 픽셀 위치
    can_img2=canvas2.create_image(200,140,image=img_list2[img_num2]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt2=canvas2_1.create_text(310,27,text=readList2[img_num2],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt2=canvas_2.create_text(130,60,text=catList2[img_num2],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath2 = '4대궁및종묘/국보_지역/부산/부산국보_한글설명.txt'
    with open(filePath2, 'rb') as lf:
        korList2 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas2_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas2_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt2_2=canvas2_2.create_text(380,190,text=korList2[img_num2],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt2_3=canvas2_2.create_text(380,380,text=page_lst2[img_num2],font=("나눔바른펜", 9, "bold"),width=100)    
    #########################################대구########################################################
    # 메인 프레임
    frame3=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame3, text="대구") 
    label = tkinter.Label(frame3,text = '대구의 국보 3점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame3, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame3)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    # 이전, 다음 버튼 함수(왜인지는 모르겠으나 한번 더 함수를 지정해야 실행이 된다..)
    img_num3=0
    def next_img_nt3():
        global img_num3     
        img_num3 += 1
        if img_num3 >= len(img_list3):
            img_num3=0
        canvas3.itemconfig(can_img3, image=img_list3[img_num3])
        canvas3_1.itemconfig(can_txt3,text=readList3[img_num3])
        canvas3_2.itemconfig(can_txt3_2,text=korList3[img_num3])
        canvas3_2.itemconfig(can_txt3_3,text=page_lst3[img_num3])
        canvas_3.itemconfig(can_dt_txt3,text=catList3[img_num3])
    def pre_img_nt3():
        global img_num3
        img_num3 -= 1
        if img_num3 < 0:
            img_num3= len(img_list3)-1
        canvas3.itemconfig(can_img3, image=img_list3[img_num3])
        canvas3_1.itemconfig(can_txt3,text=readList3[img_num3])
        canvas3_2.itemconfig(can_txt3_2,text=korList3[img_num3])
        canvas3_2.itemconfig(can_txt3_3,text=page_lst3[img_num3])
        canvas_3.itemconfig(can_dt_txt3,text=catList3[img_num3])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt3)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt3)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath3 = '4대궁및종묘/국보_지역/대구/대구국보_이름.txt'
    with open(filePath3, 'rb') as lf:
        readList3 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath3 = '4대궁및종묘/국보_지역/대구/대구국보_분류및소재지.txt'
    with open(filePath3, 'rb') as lf:
        catList3 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas3_1=Canvas(l_frame,height=37,width=1000)
    canvas3_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas3=Canvas(l_frame)
    canvas3.pack(side='left')
    # 세부 설명
    canvas_3=Canvas(l_frame,height=180,width=300)
    canvas_3.pack(side='right')

    # 사진 불러오기
    img_list3=[]
    page_lst3=[]
    for i in range(0,3):
        page3=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org3=Image.open(f"4대궁및종묘/국보_사진/대구/국보{i}.png")
        img_re3=img_org3.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img3=ImageTk.PhotoImage(img_re3,master=window3)
        img_list3.append(img3)
        page_lst3.append(page3)
    # 그림 픽셀 위치
    can_img3=canvas3.create_image(200,140,image=img_list3[img_num3]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt3=canvas3_1.create_text(310,27,text=readList3[img_num3],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt3=canvas_3.create_text(130,60,text=catList3[img_num3],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath3 = '4대궁및종묘/국보_지역/대구/대구국보_한글설명.txt'
    with open(filePath3, 'rb') as lf:
        korList3 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas3_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas3_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt3_2=canvas3_2.create_text(380,190,text=korList3[img_num3],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt3_3=canvas3_2.create_text(380,380,text=page_lst3[img_num3],font=("나눔바른펜", 9, "bold"),width=100)  
    #########################################광주########################################################
    # 메인 프레임
    frame4=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame4, text="광주") 
    label = tkinter.Label(frame4,text = '광주의 국보 2점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame4, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame4)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    # 이전, 다음 버튼 함수(왜인지는 모르겠으나 한번 더 함수를 지정해야 실행이 된다..)
    img_num4=0
    def next_img_nt4():
        global img_num4    
        img_num4 += 1
        if img_num4 >= len(img_list4):
            img_num4=0
        canvas4.itemconfig(can_img4, image=img_list4[img_num4])
        canvas4_1.itemconfig(can_txt4,text=readList4[img_num4])
        canvas4_2.itemconfig(can_txt4_2,text=korList4[img_num4])
        canvas4_2.itemconfig(can_txt4_3,text=page_lst4[img_num4])
        canvas_4.itemconfig(can_dt_txt4,text=catList4[img_num4])
    def pre_img_nt4():
        global img_num4
        img_num4 -= 1
        if img_num4 < 0:
            img_num4= len(img_list4)-1
        canvas4.itemconfig(can_img4, image=img_list4[img_num4])
        canvas4_1.itemconfig(can_txt4,text=readList4[img_num4])
        canvas4_2.itemconfig(can_txt4_2,text=korList4[img_num4])
        canvas4_2.itemconfig(can_txt4_3,text=page_lst4[img_num4])
        canvas_4.itemconfig(can_dt_txt4,text=catList4[img_num4])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt4)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt4)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath4 = '4대궁및종묘/국보_지역/광주/광주국보_이름.txt'
    with open(filePath4, 'rb') as lf:
        readList4 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath4 = '4대궁및종묘/국보_지역/광주/광주국보_분류및소재지.txt'
    with open(filePath4, 'rb') as lf:
        catList4 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas4_1=Canvas(l_frame,height=37,width=1000)
    canvas4_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas4=Canvas(l_frame)
    canvas4.pack(side='left')
    # 세부 설명
    canvas_4=Canvas(l_frame,height=180,width=300)
    canvas_4.pack(side='right')

    # 사진 불러오기
    img_list4=[]
    page_lst4=[]
    for i in range(0,2):
        page4=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org4=Image.open(f"4대궁및종묘/국보_사진/광주/국보{i}.png")
        img_re4=img_org4.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img4=ImageTk.PhotoImage(img_re4,master=window3)
        img_list4.append(img4)
        page_lst4.append(page4)
    # 그림 픽셀 위치
    can_img4=canvas4.create_image(200,140,image=img_list4[img_num4]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt4=canvas4_1.create_text(310,27,text=readList4[img_num4],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt4=canvas_4.create_text(130,60,text=catList4[img_num4],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath4 = '4대궁및종묘/국보_지역/광주/광주국보_한글설명.txt'
    with open(filePath4, 'rb') as lf:
        korList4 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas4_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas4_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt4_2=canvas4_2.create_text(380,190,text=korList4[img_num4],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt4_3=canvas4_2.create_text(380,380,text=page_lst4[img_num4],font=("나눔바른펜", 9, "bold"),width=100)   
    ###################################인천##############################################################
    # 메인 프레임
    frame5=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame5, text="인천") 
    label = tkinter.Label(frame5,text = '인천의 국보 1점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame5, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame5)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    # 이전, 다음 버튼 함수(왜인지는 모르겠으나 한번 더 함수를 지정해야 실행이 된다..)
    img_num5=0
    def next_img_nt5():
        global img_num5    
        img_num5 += 1
        if img_num5 >= len(img_list5):
            img_num5=0
        canvas5.itemconfig(can_img5, image=img_list5[img_num5])
        canvas5_1.itemconfig(can_txt5,text=readList5[img_num5])
        canvas5_2.itemconfig(can_txt5_2,text=korList5[img_num5])
        canvas5_2.itemconfig(can_txt5_3,text=page_lst5[img_num5])
        canvas_5.itemconfig(can_dt_txt5,text=catList5[img_num5])
    def pre_img_nt5():
        global img_num5
        img_num5 -= 1
        if img_num5 < 0:
            img_num5= len(img_list5)-1
        canvas5.itemconfig(can_img5, image=img_list5[img_num5])
        canvas5_1.itemconfig(can_txt5,text=readList5[img_num5])
        canvas5_2.itemconfig(can_txt5_2,text=korList5[img_num5])
        canvas5_2.itemconfig(can_txt5_3,text=page_lst5[img_num5])
        canvas_5.itemconfig(can_dt_txt5,text=catList5[img_num5])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt5)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt5)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath5 = '4대궁및종묘/국보_지역/인천/인천국보_이름.txt'
    with open(filePath5, 'rb') as lf:
        readList5 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath5 = '4대궁및종묘/국보_지역/인천/인천국보_분류및소재지.txt'
    with open(filePath5, 'rb') as lf:
        catList5 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas5_1=Canvas(l_frame,height=37,width=1000)
    canvas5_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas5=Canvas(l_frame)
    canvas5.pack(side='left')
    # 세부 설명
    canvas_5=Canvas(l_frame,height=180,width=300)
    canvas_5.pack(side='right')

    # 사진 불러오기
    img_list5=[]
    page_lst5=[]
    for i in range(0,1):
        page5=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org5=Image.open(f"4대궁및종묘/국보_사진/인천/국보{i}.png")
        img_re5=img_org5.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img5=ImageTk.PhotoImage(img_re5,master=window3)
        img_list5.append(img5)
        page_lst5.append(page5)
    # 그림 픽셀 위치
    can_img5=canvas5.create_image(200,140,image=img_list5[img_num5]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt5=canvas5_1.create_text(310,27,text=readList5[img_num5],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt5=canvas_5.create_text(130,60,text=catList5[img_num5],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath5 = '4대궁및종묘/국보_지역/인천/인천국보_한글설명.txt'
    with open(filePath5, 'rb') as lf:
        korList5 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas5_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas5_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt5_2=canvas5_2.create_text(380,190,text=korList5[img_num5],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt5_3=canvas5_2.create_text(380,380,text=page_lst5[img_num5],font=("나눔바른펜", 9, "bold"),width=100)  
    ###################################대전##############################################################
    # 메인 프레임
    frame6=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame6, text="대전") 
    label = tkinter.Label(frame6,text = '대전의 국보 1점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame6, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame6)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    # 이전, 다음 버튼 함수(왜인지는 모르겠으나 한번 더 함수를 지정해야 실행이 된다..)
    img_num6=0
    def next_img_nt6():
        global img_num6    
        img_num6 += 1
        if img_num6 >= len(img_list6):
            img_num6=0
        canvas6.itemconfig(can_img6, image=img_list6[img_num6])
        canvas6_1.itemconfig(can_txt6,text=readList6[img_num6])
        canvas6_2.itemconfig(can_txt6_2,text=korList6[img_num6])
        canvas6_2.itemconfig(can_txt6_3,text=page_lst6[img_num6])
        canvas_6.itemconfig(can_dt_txt6,text=catList6[img_num6])
    def pre_img_nt6():
        global img_num6
        img_num6 -= 1
        if img_num6 < 0:
            img_num6= len(img_list6)-1
        canvas6.itemconfig(can_img6, image=img_list6[img_num6])
        canvas6_1.itemconfig(can_txt6,text=readList6[img_num6])
        canvas6_2.itemconfig(can_txt6_2,text=korList6[img_num6])
        canvas6_2.itemconfig(can_txt6_3,text=page_lst6[img_num6])
        canvas_6.itemconfig(can_dt_txt6,text=catList6[img_num6])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt6)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt6)
    # 왼쪽에 위
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath6 = '4대궁및종묘/국보_지역/대전/대전국보_이름.txt'
    with open(filePath6, 'rb') as lf:
        readList6 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath6 = '4대궁및종묘/국보_지역/대전/대전국보_분류및소재지.txt'
    with open(filePath6, 'rb') as lf:
        catList6 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas6_1=Canvas(l_frame,height=37,width=1000)
    canvas6_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas6=Canvas(l_frame)
    canvas6.pack(side='left')
    # 세부 설명
    canvas_6=Canvas(l_frame,height=180,width=300)
    canvas_6.pack(side='right')

    # 사진 불러오기
    img_list6=[]
    page_lst6=[]
    for i in range(0,1):
        page6=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org6=Image.open(f"4대궁및종묘/국보_사진/대전/국보{i}.png")
        img_re6=img_org6.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img6=ImageTk.PhotoImage(img_re6,master=window3)
        img_list6.append(img6)
        page_lst6.append(page6)
    # 그림 픽셀 위치
    can_img6=canvas6.create_image(200,140,image=img_list6[img_num6]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt6=canvas6_1.create_text(310,27,text=readList6[img_num6],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt6=canvas_6.create_text(130,60,text=catList6[img_num6],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath6 = '4대궁및종묘/국보_지역/대전/대전국보_한글설명.txt'
    with open(filePath6, 'rb') as lf:
        korList6 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas6_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas6_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt6_2=canvas6_2.create_text(380,190,text=korList6[img_num6],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt6_3=canvas6_2.create_text(380,380,text=page_lst6[img_num6],font=("나눔바른펜", 9, "bold"),width=100)      
    ###################################울산##############################################################
    # 메인 프레임
    frame7=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame7, text="울산") 
    label = tkinter.Label(frame7,text = '울산의 국보 2점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame7, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame7)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    img_num7=0
    def next_img_nt7():
        global img_num7  
        img_num7 += 1
        if img_num7 >= len(img_list7):
            img_num7=0
        canvas7.itemconfig(can_img7, image=img_list7[img_num7])
        canvas7_1.itemconfig(can_txt7,text=readList7[img_num7])
        canvas7_2.itemconfig(can_txt7_2,text=korList7[img_num7])
        canvas7_2.itemconfig(can_txt7_3,text=page_lst7[img_num7])
        canvas_7.itemconfig(can_dt_txt7,text=catList7[img_num7])
    def pre_img_nt7():
        global img_num7
        img_num7 -= 1
        if img_num7 < 0:
            img_num7= len(img_list7)-1
        canvas7.itemconfig(can_img7, image=img_list7[img_num7])
        canvas7_1.itemconfig(can_txt7,text=readList7[img_num7])
        canvas7_2.itemconfig(can_txt7_2,text=korList7[img_num7])
        canvas7_2.itemconfig(can_txt7_3,text=page_lst7[img_num7])
        canvas_7.itemconfig(can_dt_txt7,text=catList7[img_num7])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt7)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt7)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath7 = '4대궁및종묘/국보_지역/울산/울산국보_이름.txt'
    with open(filePath7, 'rb') as lf:
        readList7 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath7 = '4대궁및종묘/국보_지역/울산/울산국보_분류및소재지.txt'
    with open(filePath7, 'rb') as lf:
        catList7 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas7_1=Canvas(l_frame,height=37,width=1000)
    canvas7_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas7=Canvas(l_frame)
    canvas7.pack(side='left')
    # 세부 설명
    canvas_7=Canvas(l_frame,height=180,width=300)
    canvas_7.pack(side='right')

    # 사진 불러오기
    img_list7=[]
    page_lst7=[]
    for i in range(0,2):
        page7=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org7=Image.open(f"4대궁및종묘/국보_사진/울산/국보{i}.png")
        img_re7=img_org7.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img7=ImageTk.PhotoImage(img_re7,master=window3)
        img_list7.append(img7)
        page_lst7.append(page7)
    # 그림 픽셀 위치
    can_img7=canvas7.create_image(200,140,image=img_list7[img_num7]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt7=canvas7_1.create_text(310,27,text=readList7[img_num7],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt7=canvas_7.create_text(130,60,text=catList7[img_num7],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath7 = '4대궁및종묘/국보_지역/울산/울산국보_한글설명.txt'
    with open(filePath7, 'rb') as lf:
        korList7 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas7_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas7_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt7_2=canvas7_2.create_text(380,190,text=korList7[img_num7],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt7_3=canvas7_2.create_text(380,380,text=page_lst7[img_num7],font=("나눔바른펜", 9, "bold"),width=100)    
    ###################################경기##############################################################
    # 메인 프레임
    frame8=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame8, text="경기") 
    label = tkinter.Label(frame8,text = '경기의 국보 13점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame8, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame8)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    img_num8=0
    def next_img_nt8():
        global img_num8  
        img_num8 += 1
        if img_num8 >= len(img_list8):
            img_num8=0
        canvas8.itemconfig(can_img8, image=img_list8[img_num8])
        canvas8_1.itemconfig(can_txt8,text=readList8[img_num8])
        canvas8_2.itemconfig(can_txt8_2,text=korList8[img_num8])
        canvas8_2.itemconfig(can_txt8_3,text=page_lst8[img_num8])
        canvas_8.itemconfig(can_dt_txt8,text=catList8[img_num8])
    def pre_img_nt8():
        global img_num8
        img_num8 -= 1
        if img_num8 < 0:
            img_num8= len(img_list8)-1
        canvas8.itemconfig(can_img8, image=img_list8[img_num8])
        canvas8_1.itemconfig(can_txt8,text=readList8[img_num8])
        canvas8_2.itemconfig(can_txt8_2,text=korList8[img_num8])
        canvas8_2.itemconfig(can_txt8_3,text=page_lst8[img_num8])
        canvas_8.itemconfig(can_dt_txt8,text=catList8[img_num8])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt8)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt8)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath8 = '4대궁및종묘/국보_지역/경기/경기국보_이름.txt'
    with open(filePath8, 'rb') as lf:
        readList8 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath8 = '4대궁및종묘/국보_지역/경기/경기국보_분류및소재지.txt'
    with open(filePath8, 'rb') as lf:
        catList8 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas8_1=Canvas(l_frame,height=37,width=1000)
    canvas8_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas8=Canvas(l_frame)
    canvas8.pack(side='left')
    # 세부 설명
    canvas_8=Canvas(l_frame,height=180,width=300)
    canvas_8.pack(side='right')

    # 사진 불러오기
    img_list8=[]
    page_lst8=[]
    for i in range(0,13):
        page8=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org8=Image.open(f"4대궁및종묘/국보_사진/경기/국보{i}.png")
        img_re8=img_org8.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img8=ImageTk.PhotoImage(img_re8,master=window3)
        img_list8.append(img8)
        page_lst8.append(page8)
    # 그림 픽셀 위치
    can_img8=canvas8.create_image(200,140,image=img_list8[img_num8]) 
    # 이름 위치(왼/오, 위/아래)
    can_txt8=canvas8_1.create_text(310,27,text=readList8[img_num8],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt8=canvas_8.create_text(130,60,text=catList8[img_num8],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath8 = '4대궁및종묘/국보_지역/경기/경기국보_한글설명.txt'
    with open(filePath8, 'rb') as lf:
        korList8 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas8_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas8_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt8_2=canvas8_2.create_text(380,190,text=korList8[img_num8],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt8_3=canvas8_2.create_text(380,380,text=page_lst8[img_num8],font=("나눔바른펜", 9, "bold"),width=100)        
    ###################################강원##############################################################
    # 메인 프레임
    frame9=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame9, text="강원") 
    label = tkinter.Label(frame9,text = '강원의 국보 12점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame9, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame9)
    r_frame.pack(side="bottom", fill="both", expand=True)   
     
    img_num9=0
    def next_img_nt9():
        global img_num9  
        img_num9 += 1
        if img_num9 >= len(img_list9):
            img_num9=0
        canvas9.itemconfig(can_img9, image=img_list9[img_num9])
        canvas9_1.itemconfig(can_txt9,text=readList9[img_num9])
        canvas9_2.itemconfig(can_txt9_2,text=korList9[img_num9])
        canvas9_2.itemconfig(can_txt9_3,text=page_lst9[img_num9])
        canvas_9.itemconfig(can_dt_txt9,text=catList9[img_num9])
    def pre_img_nt9():
        global img_num9
        img_num9 -= 1
        if img_num9 < 0:
            img_num9= len(img_list9)-1
        canvas9.itemconfig(can_img9, image=img_list9[img_num9])
        canvas9_1.itemconfig(can_txt9,text=readList9[img_num9])
        canvas9_2.itemconfig(can_txt9_2,text=korList9[img_num9])
        canvas9_2.itemconfig(can_txt9_3,text=page_lst9[img_num9])
        canvas_9.itemconfig(can_dt_txt9,text=catList9[img_num9])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt9)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt9)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath9 = '4대궁및종묘/국보_지역/강원/강원국보_이름.txt'
    with open(filePath9, 'rb') as lf:
        readList9 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath9 = '4대궁및종묘/국보_지역/강원/강원국보_분류및소재지.txt'
    with open(filePath9, 'rb') as lf:
        catList9 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas9_1=Canvas(l_frame,height=37,width=1000)
    canvas9_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas9=Canvas(l_frame)
    canvas9.pack(side='left')
    # 세부 설명
    canvas_9=Canvas(l_frame,height=180,width=300)
    canvas_9.pack(side='right')

    # 사진 불러오기
    img_list9=[]
    page_lst9=[]
    for i in range(0,12):
        page9=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org9=Image.open(f"4대궁및종묘/국보_사진/강원/국보{i}.png")
        img_re9=img_org9.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img9=ImageTk.PhotoImage(img_re9,master=window3)
        img_list9.append(img9)
        page_lst9.append(page9)
    # 그림 픽셀 위치
    can_img9=canvas9.create_image(200,140,image=img_list9[img_num9]) 
    # 이름 위치(왼/오, 위/아래
    can_txt9=canvas9_1.create_text(310,27,text=readList9[img_num9],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt9=canvas_9.create_text(130,60,text=catList9[img_num9],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath9 = '4대궁및종묘/국보_지역/강원/강원국보_한글설명.txt'
    with open(filePath9, 'rb') as lf:
        korList9 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas9_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas9_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt9_2=canvas9_2.create_text(380,190,text=korList9[img_num9],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt9_3=canvas9_2.create_text(380,380,text=page_lst9[img_num9],font=("나눔바른펜", 9, "bold"),width=100)       
    ###################################충북##############################################################
    # 메인 프레임
    frame10=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame10, text="충북") 
    label = tkinter.Label(frame10,text = '충북의 국보 12점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame10, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame10)
    r_frame.pack(side="bottom", fill="both", expand=True)   

    img_num10=0
    def next_img_nt10():
        global img_num10 
        img_num10 += 1
        if img_num10 >= len(img_list10):
            img_num10=0
        canvas10.itemconfig(can_img10, image=img_list10[img_num10])
        canvas10_1.itemconfig(can_txt10,text=readList10[img_num10])
        canvas10_2.itemconfig(can_txt10_2,text=korList10[img_num10])
        canvas10_2.itemconfig(can_txt10_3,text=page_lst10[img_num10])
        canvas_10.itemconfig(can_dt_txt10,text=catList10[img_num10])
    def pre_img_nt10():
        global img_num10
        img_num10 -= 1
        if img_num10 < 0:
            img_num10= len(img_list10)-1
        canvas10.itemconfig(can_img10, image=img_list10[img_num10])
        canvas10_1.itemconfig(can_txt10,text=readList10[img_num10])
        canvas10_2.itemconfig(can_txt10_2,text=korList10[img_num10])
        canvas10_2.itemconfig(can_txt10_3,text=page_lst10[img_num10])
        canvas_10.itemconfig(can_dt_txt10,text=catList10[img_num10])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt10)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt10)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath10 = '4대궁및종묘/국보_지역/충북/충북국보_이름.txt'
    with open(filePath10, 'rb') as lf:
        readList10 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath10 = '4대궁및종묘/국보_지역/충북/충북국보_분류및소재지.txt'
    with open(filePath10, 'rb') as lf:
        catList10 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas10_1=Canvas(l_frame,height=37,width=1000)
    canvas10_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas10=Canvas(l_frame)
    canvas10.pack(side='left')
    # 세부 설명
    canvas_10=Canvas(l_frame,height=180,width=300)
    canvas_10.pack(side='right')

    # 사진 불러오기
    img_list10=[]
    page_lst10=[]
    for i in range(0,12):
        page10=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org10=Image.open(f"4대궁및종묘/국보_사진/충북/국보{i}.png")
        img_re10=img_org10.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img10=ImageTk.PhotoImage(img_re10,master=window3)
        img_list10.append(img10)
        page_lst10.append(page10)
    # 그림 픽셀 위치
    can_img10=canvas10.create_image(200,140,image=img_list10[img_num10]) 
    # 이름 위치(왼/오, 위/아래
    can_txt10=canvas10_1.create_text(310,27,text=readList10[img_num10],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt10=canvas_10.create_text(130,60,text=catList10[img_num10],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath10 = '4대궁및종묘/국보_지역/충북/충북국보_한글설명.txt'
    with open(filePath10, 'rb') as lf:
        korList10 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas10_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas10_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt10_2=canvas10_2.create_text(380,190,text=korList10[img_num10],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt10_3=canvas10_2.create_text(380,380,text=page_lst10[img_num10],font=("나눔바른펜", 9, "bold"),width=100)       
    ###################################충남##############################################################
    # 메인 프레임
    frame11=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame11, text="충남") 
    label = tkinter.Label(frame11,text = '충남의 국보 31점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame11, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame11)
    r_frame.pack(side="bottom", fill="both", expand=True)   

    img_num11=0
    def next_img_nt11():
        global img_num11 
        img_num11 += 1
        if img_num11 >= len(img_list11):
            img_num11=0
        canvas11.itemconfig(can_img11, image=img_list11[img_num11])
        canvas11_1.itemconfig(can_txt11,text=readList11[img_num11])
        canvas11_2.itemconfig(can_txt11_2,text=korList11[img_num11])
        canvas11_2.itemconfig(can_txt11_3,text=page_lst11[img_num11])
        canvas_11.itemconfig(can_dt_txt11,text=catList11[img_num11])
    def pre_img_nt11():
        global img_num11
        img_num11 -= 1
        if img_num11 < 0:
            img_num11= len(img_list11)-1
        canvas11.itemconfig(can_img11, image=img_list11[img_num11])
        canvas11_1.itemconfig(can_txt11,text=readList11[img_num11])
        canvas11_2.itemconfig(can_txt11_2,text=korList11[img_num11])
        canvas11_2.itemconfig(can_txt11_3,text=page_lst11[img_num11])
        canvas_11.itemconfig(can_dt_txt11,text=catList11[img_num11])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt11)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt11)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath11 = '4대궁및종묘/국보_지역/충남/충남국보_이름.txt'
    with open(filePath11, 'rb') as lf:
        readList11 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath11 = '4대궁및종묘/국보_지역/충남/충남국보_분류및소재지.txt'
    with open(filePath11, 'rb') as lf:
        catList11 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas11_1=Canvas(l_frame,height=37,width=1000)
    canvas11_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas11=Canvas(l_frame)
    canvas11.pack(side='left')
    # 세부 설명
    canvas_11=Canvas(l_frame,height=180,width=300)
    canvas_11.pack(side='right')

    # 사진 불러오기
    img_list11=[]
    page_lst11=[]
    for i in range(0,31):
        page11=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org11=Image.open(f"4대궁및종묘/국보_사진/충남/국보{i}.png")
        img_re11=img_org11.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img11=ImageTk.PhotoImage(img_re11,master=window3)
        img_list11.append(img11)
        page_lst11.append(page11)
    # 그림 픽셀 위치
    can_img11=canvas11.create_image(200,140,image=img_list11[img_num11]) 
    # 이름 위치(왼/오, 위/아래
    can_txt11=canvas11_1.create_text(310,27,text=readList11[img_num11],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt11=canvas_11.create_text(130,60,text=catList11[img_num11],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath11 = '4대궁및종묘/국보_지역/충남/충남국보_한글설명.txt'
    with open(filePath11, 'rb') as lf:
        korList11 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas11_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas11_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt11_2=canvas11_2.create_text(380,190,text=korList11[img_num11],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt11_3=canvas11_2.create_text(380,380,text=page_lst11[img_num11],font=("나눔바른펜", 9, "bold"),width=100)    
    #################################전북################################################################
    # 메인 프레임
    frame12=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame12, text="전북") 
    label = tkinter.Label(frame12,text = '전북의 국보 8점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame12, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame12)
    r_frame.pack(side="bottom", fill="both", expand=True)   

    img_num12=0
    def next_img_nt12():
        global img_num12
        img_num12 += 1
        if img_num12 >= len(img_list12):
            img_num12=0
        canvas12.itemconfig(can_img12, image=img_list12[img_num12])
        canvas12_1.itemconfig(can_txt12,text=readList12[img_num12])
        canvas12_2.itemconfig(can_txt12_2,text=korList12[img_num12])
        canvas12_2.itemconfig(can_txt12_3,text=page_lst12[img_num12])
        canvas_12.itemconfig(can_dt_txt12,text=catList12[img_num12])
    def pre_img_nt12():
        global img_num12
        img_num12 -= 1
        if img_num12 < 0:
            img_num12= len(img_list12)-1
        canvas12.itemconfig(can_img12, image=img_list12[img_num12])
        canvas12_1.itemconfig(can_txt12,text=readList12[img_num12])
        canvas12_2.itemconfig(can_txt12_2,text=korList12[img_num12])
        canvas12_2.itemconfig(can_txt12_3,text=page_lst12[img_num12])
        canvas_12.itemconfig(can_dt_txt12,text=catList12[img_num12])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt12)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt12)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath12 = '4대궁및종묘/국보_지역/전북/전북국보_이름.txt'
    with open(filePath12, 'rb') as lf:
        readList12 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath12 = '4대궁및종묘/국보_지역/전북/전북국보_분류및소재지.txt'
    with open(filePath12, 'rb') as lf:
        catList12 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas12_1=Canvas(l_frame,height=37,width=1000)
    canvas12_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas12=Canvas(l_frame)
    canvas12.pack(side='left')
    # 세부 설명
    canvas_12=Canvas(l_frame,height=180,width=300)
    canvas_12.pack(side='right')

    # 사진 불러오기
    img_list12=[]
    page_lst12=[]
    for i in range(0,8):
        page12=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org12=Image.open(f"4대궁및종묘/국보_사진/전북/국보{i}.png")
        img_re12=img_org12.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img12=ImageTk.PhotoImage(img_re12,master=window3)
        img_list12.append(img12)
        page_lst12.append(page12)
    # 그림 픽셀 위치
    can_img12=canvas12.create_image(200,140,image=img_list12[img_num12]) 
    # 이름 위치(왼/오, 위/아래
    can_txt12=canvas12_1.create_text(310,27,text=readList12[img_num12],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt12=canvas_12.create_text(130,60,text=catList12[img_num12],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath12 = '4대궁및종묘/국보_지역/전북/전북국보_한글설명.txt'
    with open(filePath12, 'rb') as lf:
        korList12 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas12_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas12_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt12_2=canvas12_2.create_text(380,190,text=korList12[img_num12],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt12_3=canvas12_2.create_text(380,380,text=page_lst12[img_num12],font=("나눔바른펜", 9, "bold"),width=100)  
    #################################전남################################################################
    # 메인 프레임
    frame13=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame13, text="전남") 
    label = tkinter.Label(frame13,text = '전남의 국보 22점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame13, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame13)
    r_frame.pack(side="bottom", fill="both", expand=True)   

    img_num13=0
    def next_img_nt13():
        global img_num13
        img_num13 += 1
        if img_num13 >= len(img_list13):
            img_num13=0
        canvas13.itemconfig(can_img13, image=img_list13[img_num13])
        canvas13_1.itemconfig(can_txt13,text=readList13[img_num13])
        canvas13_2.itemconfig(can_txt13_2,text=korList13[img_num13])
        canvas13_2.itemconfig(can_txt13_3,text=page_lst13[img_num13])
        canvas_13.itemconfig(can_dt_txt13,text=catList13[img_num13])
    def pre_img_nt13():
        global img_num13
        img_num13 -= 1
        if img_num13 < 0:
            img_num13= len(img_list13)-1
        canvas13.itemconfig(can_img13, image=img_list13[img_num13])
        canvas13_1.itemconfig(can_txt13,text=readList13[img_num13])
        canvas13_2.itemconfig(can_txt13_2,text=korList13[img_num13])
        canvas13_2.itemconfig(can_txt13_3,text=page_lst13[img_num13])
        canvas_13.itemconfig(can_dt_txt13,text=catList13[img_num13])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt13)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt13)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath13 = '4대궁및종묘/국보_지역/전남/전남국보_이름.txt'
    with open(filePath13, 'rb') as lf:
        readList13 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath13 = '4대궁및종묘/국보_지역/전남/전남국보_분류및소재지.txt'
    with open(filePath13, 'rb') as lf:
        catList13 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas13_1=Canvas(l_frame,height=37,width=1000)
    canvas13_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas13=Canvas(l_frame)
    canvas13.pack(side='left')
    # 세부 설명
    canvas_13=Canvas(l_frame,height=180,width=300)
    canvas_13.pack(side='right')

    # 사진 불러오기
    img_list13=[]
    page_lst13=[]
    for i in range(0,22):
        page13=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org13=Image.open(f"4대궁및종묘/국보_사진/전남/국보{i}.png")
        img_re13=img_org13.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img13=ImageTk.PhotoImage(img_re13,master=window3)
        img_list13.append(img13)
        page_lst13.append(page13)
    # 그림 픽셀 위치
    can_img13=canvas13.create_image(200,140,image=img_list13[img_num13]) 
    # 이름 위치(왼/오, 위/아래
    can_txt13=canvas13_1.create_text(310,27,text=readList13[img_num13],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt13=canvas_13.create_text(130,60,text=catList13[img_num13],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath13 = '4대궁및종묘/국보_지역/전남/전남국보_한글설명.txt'
    with open(filePath13, 'rb') as lf:
        korList13 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas13_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas13_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt13_2=canvas13_2.create_text(380,190,text=korList13[img_num13],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt13_3=canvas13_2.create_text(380,380,text=page_lst13[img_num13],font=("나눔바른펜", 9, "bold"),width=100) 
    #################################경북################################################################
    # 메인 프레임
    frame14=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame14, text="경북") 
    label = tkinter.Label(frame14,text = '경북의 국보 56점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame14, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame14)
    r_frame.pack(side="bottom", fill="both", expand=True)   

    img_num14=0
    def next_img_nt14():
        global img_num14
        img_num14 += 1
        if img_num14 >= len(img_list14):
            img_num14=0
        canvas14.itemconfig(can_img14, image=img_list14[img_num14])
        canvas14_1.itemconfig(can_txt14,text=readList14[img_num14])
        canvas14_2.itemconfig(can_txt14_2,text=korList14[img_num14])
        canvas14_2.itemconfig(can_txt14_3,text=page_lst14[img_num14])
        canvas_14.itemconfig(can_dt_txt14,text=catList14[img_num14])
    def pre_img_nt14():
        global img_num14
        img_num14 -= 1
        if img_num14 < 0:
            img_num14= len(img_list14)-1
        canvas14.itemconfig(can_img14, image=img_list14[img_num14])
        canvas14_1.itemconfig(can_txt14,text=readList14[img_num14])
        canvas14_2.itemconfig(can_txt14_2,text=korList14[img_num14])
        canvas14_2.itemconfig(can_txt14_3,text=page_lst14[img_num14])
        canvas_14.itemconfig(can_dt_txt14,text=catList14[img_num14])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt14)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt14)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath14 = '4대궁및종묘/국보_지역/경북/경북국보_이름.txt'
    with open(filePath14, 'rb') as lf:
        readList14 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath14 = '4대궁및종묘/국보_지역/경북/경북국보_분류및소재지.txt'
    with open(filePath14, 'rb') as lf:
        catList14 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas14_1=Canvas(l_frame,height=37,width=1000)
    canvas14_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas14=Canvas(l_frame)
    canvas14.pack(side='left')
    # 세부 설명
    canvas_14=Canvas(l_frame,height=180,width=300)
    canvas_14.pack(side='right')

    # 사진 불러오기
    img_list14=[]
    page_lst14=[]
    for i in range(0,56):
        page14=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org14=Image.open(f"4대궁및종묘/국보_사진/경북/국보{i}.png")
        img_re14=img_org14.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img14=ImageTk.PhotoImage(img_re14,master=window3)
        img_list14.append(img14)
        page_lst14.append(page14)
    # 그림 픽셀 위치
    can_img14=canvas14.create_image(200,140,image=img_list14[img_num14]) 
    # 이름 위치(왼/오, 위/아래
    can_txt14=canvas14_1.create_text(310,27,text=readList14[img_num14],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt14=canvas_14.create_text(130,60,text=catList14[img_num14],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath14 = '4대궁및종묘/국보_지역/경북/경북국보_한글설명.txt'
    with open(filePath14, 'rb') as lf:
        korList14 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas14_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas14_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt14_2=canvas14_2.create_text(380,190,text=korList14[img_num14],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt14_3=canvas14_2.create_text(380,380,text=page_lst14[img_num14],font=("나눔바른펜", 9, "bold"),width=100) 
    #################################경남################################################################
    # 메인 프레임
    frame15=tkinter.LabelFrame(window3, width=800, height=800)
    notebook.add(frame15, text="경남") 
    label = tkinter.Label(frame15,text = '경남의 국보 14점',font=("나눔바른펜", 12, "bold"), fg='skyblue') # top 쪽에 올라감
    label.pack()       
    # 탭 안의 페이지  
    # 위 프레임(원래 왼/오 프레임이여서 변수명이 이렇다..)
    l_frame=tkinter.Frame(frame15, relief="solid", bd=1) #,height=200,width=200)
    l_frame.pack(side="top", fill="both", expand=True)
    # 아래 프레임
    r_frame=tkinter.Frame(frame15)
    r_frame.pack(side="bottom", fill="both", expand=True)   

    img_num15=0
    def next_img_nt15():
        global img_num15
        img_num15 += 1
        if img_num15 >= len(img_list15):
            img_num15=0
        canvas15.itemconfig(can_img15, image=img_list15[img_num15])
        canvas15_1.itemconfig(can_txt15,text=readList15[img_num15])
        canvas15_2.itemconfig(can_txt15_2,text=korList15[img_num15])
        canvas15_2.itemconfig(can_txt15_3,text=page_lst15[img_num15])
        canvas_15.itemconfig(can_dt_txt15,text=catList15[img_num15])
    def pre_img_nt15():
        global img_num15
        img_num15 -= 1
        if img_num15 < 0:
            img_num15= len(img_list15)-1
        canvas15.itemconfig(can_img15, image=img_list15[img_num15])
        canvas15_1.itemconfig(can_txt15,text=readList15[img_num15])
        canvas15_2.itemconfig(can_txt15_2,text=korList15[img_num15])
        canvas15_2.itemconfig(can_txt15_3,text=page_lst15[img_num15])
        canvas_15.itemconfig(can_dt_txt15,text=catList15[img_num15])
    # 다음 버튼 생성
    button2=Button(l_frame, text="다음▶",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=next_img_nt15)
    button2.pack(side='right')
    # 이전 버튼 생성
    button1=Button(l_frame, text="이전◀",font=("나눔바른펜", 15, "bold"), width=5, bg="lightblue", command=pre_img_nt15)
    # 왼쪽에 위치
    button1.pack(side='left')
        
    # 이름 리스트 읽어오기
    filePath15 = '4대궁및종묘/국보_지역/경남/경남국보_이름.txt'
    with open(filePath15, 'rb') as lf:
        readList15 = pickle.load(lf)
        
    # 분류및소재지 리스트 읽어오기
    filePath15 = '4대궁및종묘/국보_지역/경남/경남국보_분류및소재지.txt'
    with open(filePath15, 'rb') as lf:
        catList15 = pickle.load(lf)    
        
    # 이름 넣을 도화지, 이름 도화지의 크기
    canvas15_1=Canvas(l_frame,height=37,width=1000)
    canvas15_1.pack(side='top')    
    # 이미지 넣을 도화지
    canvas15=Canvas(l_frame)
    canvas15.pack(side='left')
    # 세부 설명
    canvas_15=Canvas(l_frame,height=180,width=300)
    canvas_15.pack(side='right')

    # 사진 불러오기
    img_list15=[]
    page_lst15=[]
    for i in range(0,14):
        page15=f'page{i+1}'
        # 이미지 크기 조정을 위해 원본을 불러옴
        img_org15=Image.open(f"4대궁및종묘/국보_사진/경남/국보{i}.png")
        img_re15=img_org15.resize((380,280),Image.ANTIALIAS)
        # 크기 조정한 이미지를 리스트에
        img15=ImageTk.PhotoImage(img_re15,master=window3)
        img_list15.append(img15)
        page_lst15.append(page15)
    # 그림 픽셀 위치
    can_img15=canvas15.create_image(200,140,image=img_list15[img_num15]) 
    # 이름 위치(왼/오, 위/아래
    can_txt15=canvas15_1.create_text(310,27,text=readList15[img_num15],font=("나눔바른펜", 12, "bold"))  
    # 세부 설명 위치
    can_dt_txt15=canvas_15.create_text(130,60,text=catList15[img_num15],font=("나눔바른펜", 12, "bold"),width=220)
    ###########아래 프레임##############   
    # 한글설명 리스트 읽어오기
    filePath15 = '4대궁및종묘/국보_지역/경남/경남국보_한글설명.txt'
    with open(filePath15, 'rb') as lf:
        korList15 = pickle.load(lf)
    # 설명이 들어갈 캔버스    
    canvas15_2=Canvas(r_frame,width=390, height=390,bg='ivory')
    canvas15_2.pack(side='top',fill="both", expand=True)
    # 설명 텍스트 위치
    can_txt15_2=canvas15_2.create_text(380,190,text=korList15[img_num15],font=("나눔바른펜", 9, "bold"),width=700)
    # page 번호
    can_txt15_3=canvas15_2.create_text(380,380,text=page_lst15[img_num15],font=("나눔바른펜", 9, "bold"),width=100)

    window3.mainloop()
############################

###########메인 페이지####################################################################################################    
window=Tk()
window.title("한국의 문화 유산")
window.resizable(False, False)
window.geometry("800x700")
window.config(padx=10, pady=10)
st=tkinter.ttk.Style()
st.theme_use('clam')

canvas=Canvas(window, height=800, width=850, bg='ivory')
canvas.pack()
# 배경사진
img=PhotoImage(file="star.png")
canvas.create_image(350,250,image=img)
# 350 250
tit=canvas.create_text(150,80,text='한국의 문화 유산', fill='white', font=("나눔바른펜",25,"bold"))

sub=canvas.create_text(150,80,text='', fill='white', font=("나눔바른펜",25,"bold"))

button1 = Button(window, text="4대궁 및 종묘",width=15, height=3,
                 font=("나눔바른펜", 15, "bold"), bg="ivory",command=click_btn)
button1.place(x=40,y=120)

button2 = Button(window, text="국보",width=15, height=3, 
                 font=("나눔바른펜", 15, "bold"), bg="ivory",command=click_btn2)
button2.place(x=40,y=220)
    
# button3 = Button(window,text="대한민국의 지역의 국보현황",width=45, height=3, 
#                  font=("나눔바른펜", 15, "bold"), bg="pink",command=click_btn2)
# button3.place(x=40,y=520)

window.mainloop()
